# %%
import torch
import numpy as np

# %%
a = torch.tensor([[2, 5, 1], [8, 9, 11]])
a
# Out:
# tensor([[ 2,  5,  1],
#         [ 8,  9, 11]])

# %%
b = torch.tensor([[3, 8, 2], [7, 4, 6]])
a
# Out:
# tensor([[ 2,  5,  1],
#         [ 8,  9, 11]])

# %%
a.T
# Out:
# tensor([[ 2,  8],
#         [ 5,  9],
#         [ 1, 11]])

# %%
torch.matmul(a.T, b)
# Out:
# tensor([[62, 48, 52],
#         [78, 76, 64],
#         [80, 52, 68]])

# %%
torch.matmul(b, a.T)
# Out:
# tensor([[ 48, 118],
#         [ 40, 158]])

# %%
sym_mt = torch.tensor([[1,2,3], [2,4, 4], [3, 4, 6]])
sym_mt
# Out:
# tensor([[1, 2, 3],
#         [2, 4, 4],
#         [3, 4, 6]])

# %%
sym_mt.T
# Out:
# tensor([[1, 2, 3],
#         [2, 4, 4],
#         [3, 4, 6]])

# %%
sym_mt.T == sym_mt
# Out:
# tensor([[True, True, True],
#         [True, True, True],
#         [True, True, True]])

# %%
I = np.array([[1,0,0], [0,1,0], [0,0,1]])
I
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]])

# %%
first_column = I[:, 0]
first_column
# Out:
# array([1, 0, 0])

# %%
second_column = I[:, 1]
second_column
# Out:
# array([0, 1, 0])

# %%
third_column = I[:, 2]
third_column
# Out:
# array([0, 0, 1])

# %%
summ = 0
for e in first_column:
    e = e * e
    summ += e
np.square(summ)
# Out:
# np.int64(1)

# %%
summ = 0
for e in second_column:
    e = e * e
    summ += e
np.square(summ)
# Out:
# np.int64(1)

# %%
summ = 0
for e in third_column:
    e = e * e
    summ += e
np.square(summ)
# Out:
# np.int64(1)

# %%
np.linalg.norm(first_column), np.linalg.norm(second_column), np.linalg.norm(third_column)
# Out:
# (np.float64(1.0), np.float64(1.0), np.float64(1.0))

# %%
K = np.array([[2/3, 1/3, 2/3], [-2/3, 2/3, 1/3], [1/3, 2/3, -2/3]])
K
# Out:
# array([[ 0.66666667,  0.33333333,  0.66666667],
#        [-0.66666667,  0.66666667,  0.33333333],
#        [ 0.33333333,  0.66666667, -0.66666667]])

# %%
for i in range(3):
    col = K[:, i]
    norm = np.linalg.norm(col)
    print(f"Norm of column {i}: {norm}")
# Out:
# Norm of column 0: 0.9999999999999999
# Norm of column 1: 0.9999999999999999
# Norm of column 2: 0.9999999999999999

# %%
# Orthogonal matrix property check

torch.matmul(torch.tensor(K.T, dtype=torch.float32), torch.tensor(K, dtype=torch.float32))
# Out:
# tensor([[1.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000]])

# %%
u1 = np.array([2,5, -3])
u2 = np.array([0, -4, 6])
u1, u2
# Out:
# (array([ 2,  5, -3]), array([ 0, -4,  6]))

# %%
matrix_u = np.concatenate((u1.reshape(3,1), u2.reshape(3,1)), axis=1)
matrix_u
# Out:
# array([[ 2,  0],
#        [ 5, -4],
#        [-3,  6]])

# %%
B = np.array([[2, 0, -1], [-2, 3, 1], [0, 4, -1]])

# %%
import torch
B = torch.tensor(B, dtype=torch.float32)
B
# Out:
# tensor([[ 2.,  0., -1.],
#         [-2.,  3.,  1.],
#         [ 0.,  4., -1.]])

# %%
u1 = torch.tensor(u1, dtype=torch.float32)
u1
# Out:
# tensor([ 2.,  5., -3.])

# %%
B.matmul(u1)
# Out:
# tensor([ 7.,  8., 23.])

# %%
X = torch.tensor([[25, 2, 9], [5,26, -5], [3, 7, -14]], dtype=torch.float32)
X
# Out:
# tensor([[ 25.,   2.,   9.],
#         [  5.,  26.,  -5.],
#         [  3.,   7., -14.]])

# %%
eigen_values, eigen_vectors = torch.linalg.eig(X)
eigen_values.dtype, eigen_vectors.dtype
# Out:
# (torch.complex64, torch.complex64)

# %%
X = X.to(eigen_values.dtype)

# %%
torch.allclose(X.matmul(eigen_vectors), eigen_vectors.matmul(torch.diag(eigen_values)))
# Out:
# True

# %%
A = torch.tensor([[-1, 4], [2, -2.]])
A
# Out:
# tensor([[-1.,  4.],
#         [ 2., -2.]])

# %%
eig_v, eig_vec = torch.linalg.eig(A)
eig_v, eig_vec
# Out:
# (tensor([ 1.3723+0.j, -4.3723+0.j]),
#  tensor([[ 0.8601+0.j, -0.7645+0.j],
#          [ 0.5101+0.j,  0.6446+0.j]]))

# %%
A = A.to(eig_v.dtype)
A
# Out:
# tensor([[-1.+0.j,  4.+0.j],
#         [ 2.+0.j, -2.+0.j]])

# %%
vec1 = eig_vec[:, 0]
val1 = eig_v[0]
vec1, val1
# Out:
# (tensor([0.8601+0.j, 0.5101+0.j]), tensor(1.3723+0.j))

# %%
Av_p = A.matmul(vec1)
Av_p
# Out:
# tensor([1.1803+0.j, 0.7000+0.j])

# %%
vec1 * val1
# Out:
# tensor([1.1803+0.j, 0.7000+0.j])

# %%
val2 = eig_v[1]
vec2 = eig_vec[:, 1]
val2, vec2
# Out:
# (tensor(-4.3723+0.j), tensor([-0.7645+0.j,  0.6446+0.j]))

# %%
Av2_P = A.matmul(vec2)
Av2_P
# Out:
# tensor([ 3.3428+0.j, -2.8182+0.j])

# %%
val2 * vec2
# Out:
# tensor([ 3.3428-0.j, -2.8182+0.j])

# %%
X = torch.tensor([[25, 2, 9], [5, 26, -5], [3, 7, -14.]])
X
# Out:
# tensor([[ 25.,   2.,   9.],
#         [  5.,  26.,  -5.],
#         [  3.,   7., -14.]])

# %%
eig_val, eig_vec = torch.linalg.eig(X)
eig_val, eig_vec
# Out:
# (tensor([ 29.4214+0.j,  21.2058+0.j, -13.6271+0.j]),
#  tensor([[ 0.6633+0.j,  0.6360+0.j, -0.2317+0.j],
#          [ 0.7303+0.j, -0.7655+0.j,  0.1505+0.j],
#          [ 0.1636+0.j, -0.0980+0.j,  0.9611+0.j]]))

# %%
X = X.to(eig_vec.dtype)
X
# Out:
# tensor([[ 25.+0.j,   2.+0.j,   9.+0.j],
#         [  5.+0.j,  26.+0.j,  -5.+0.j],
#         [  3.+0.j,   7.+0.j, -14.+0.j]])

# %%
eig_vec1 = eig_vec[:, 0]
eig_val1 = eig_val[0]
eig_vec1, eig_val1
# Out:
# (tensor([0.6633+0.j, 0.7303+0.j, 0.1636+0.j]), tensor(29.4214+0.j))

# %%
X.matmul(eig_vec1)
# Out:
# tensor([19.5144+0.j, 21.4861+0.j,  4.8120+0.j])

# %%
eig_val1 * eig_vec1
# Out:
# tensor([19.5144+0.j, 21.4861+0.j,  4.8120+0.j])

# %%
torch.allclose(X.matmul(eig_vec1), eig_val1 * eig_vec1)
# Out:
# True

# %%
eig_vec2 = eig_vec[:, 1]
eig_val2 = eig_val[1]
eig_vec2, eig_val2
# Out:
# (tensor([ 0.6360+0.j, -0.7655+0.j, -0.0980+0.j]), tensor(21.2058+0.j))

# %%
X.matmul(eig_vec2)
# Out:
# tensor([ 13.4861+0.j, -16.2324+0.j,  -2.0783+0.j])

# %%
eig_val2 * eig_vec2
# Out:
# tensor([ 13.4861+0.j, -16.2324+0.j,  -2.0783+0.j])

# %%
eig_vec3 = eig_vec[:, 2]
eig_val3 = eig_val[2]
eig_vec3, eig_val3
# Out:
# (tensor([-0.2317+0.j,  0.1505+0.j,  0.9611+0.j]), tensor(-13.6271+0.j))

# %%
X.matmul(eig_vec3)
# Out:
# tensor([  3.1577+0.j,  -2.0509+0.j, -13.0966+0.j])

# %%
eig_val3 * eig_vec3
# Out:
# tensor([  3.1577-0.j,  -2.0509+0.j, -13.0966+0.j])

# %%
B_det = torch.tensor([[-2, 0], [0, -2.]])
B_det
# Out:
# tensor([[-2.,  0.],
#         [ 0., -2.]])

# %%
torch.linalg.det(B_det)
# Out:
# tensor(4.)

# %%
C_det = torch.tensor([[2,1,-3], [4,-5,2], [0,-1,3.]])
C_det
# Out:
# tensor([[ 2.,  1., -3.],
#         [ 4., -5.,  2.],
#         [ 0., -1.,  3.]])

# %%
torch.linalg.det(C_det)
# Out:
# tensor(-26.)

# %%
import torch

P = torch.tensor([[25, 2, -5], [3, -2, 1], [5, 7, 4.]])
S = torch.tensor([[25, 2, -5], [2, -2 ,1], [ -5, 1, 4.]])
S, P
# Out:
# (tensor([[25.,  2., -5.],
#          [ 2., -2.,  1.],
#          [-5.,  1.,  4.]]),
#  tensor([[25.,  2., -5.],
#          [ 3., -2.,  1.],
#          [ 5.,  7.,  4.]]))

# %%
P_eigen_values, P_eigen_vectors = torch.linalg.eig(P)
P_eigen_values, P_eigen_vectors
# Out:
# (tensor([23.7644+0.j,  6.6684+0.j, -3.4328+0.j]),
#  tensor([[ 0.9511+0.j, -0.2386+0.j,  0.1626+0.j],
#          [ 0.1218+0.j, -0.1924+0.j, -0.7705+0.j],
#          [ 0.2837+0.j, -0.9519+0.j,  0.6163+0.j]]))

# %%
P_eigenval_diag = P_eigen_values.diag()
P_eigenval_diag
# Out:
# tensor([[23.7644+0.j,  0.0000+0.j,  0.0000+0.j],
#         [ 0.0000+0.j,  6.6684+0.j,  0.0000+0.j],
#         [ 0.0000+0.j,  0.0000+0.j, -3.4328+0.j]])

# %%
P_eigen_vectors_inv = torch.linalg.inv(P_eigen_vectors)
P_eigen_vectors_inv
# Out:
# tensor([[ 1.1356+0.j,  0.0102+0.j, -0.2868+0.j],
#         [ 0.3914-0.j, -0.7198-0.j, -1.0032-0.j],
#         [ 0.0817-0.j, -1.1164-0.j,  0.2052-0.j]])

# %%
torch.matmul(P_eigen_vectors, torch.matmul(P_eigenval_diag, P_eigen_vectors_inv))
# Out:
# tensor([[25.0000+0.j,  2.0000+0.j, -5.0000+0.j],
#         [ 3.0000+0.j, -2.0000+0.j,  1.0000+0.j],
#         [ 5.0000+0.j,  7.0000+0.j,  4.0000+0.j]])

# %%
P
# Out:
# tensor([[25.,  2., -5.],
#         [ 3., -2.,  1.],
#         [ 5.,  7.,  4.]])

# %%
S_eigen_values, S_eigen_vectors = torch.linalg.eig(S)
S_eigen_values, S_eigen_vectors
# Out:
# (tensor([26.2361+0.j,  3.2435+0.j, -2.4796+0.j]),
#  tensor([[ 0.9744+0.j,  0.1943+0.j, -0.1132+0.j],
#          [ 0.0614+0.j,  0.2548+0.j,  0.9651+0.j],
#          [-0.2163+0.j,  0.9473+0.j, -0.2363+0.j]]))

# %%
torch.matmul(S_eigen_vectors, torch.matmul(S_eigen_values.diag(), S_eigen_vectors.T))
# Out:
# tensor([[25.0000+0.j,  2.0000+0.j, -5.0000+0.j],
#         [ 2.0000+0.j, -2.0000+0.j,  1.0000+0.j],
#         [-5.0000+0.j,  1.0000+0.j,  4.0000+0.j]])

# %%
S
# Out:
# tensor([[25.,  2., -5.],
#         [ 2., -2.,  1.],
#         [-5.,  1.,  4.]])

# %%
import numpy as np

A = np.array([[-1, 2], [3, -2], [5,7]])
A
# Out:
# array([[-1,  2],
#        [ 3, -2],
#        [ 5,  7]])

# %%
U, d, vT = np.linalg.svd(A)
U, d, vT
# Out:
# (array([[ 0.12708324,  0.47409506,  0.87125411],
#         [ 0.00164602, -0.87847553,  0.47778451],
#         [ 0.99189069, -0.0592843 , -0.11241989]]),
#  array([8.66918448, 4.10429538]),
#  array([[ 0.55798885,  0.82984845],
#         [-0.82984845,  0.55798885]]))

# %%
D = np.concatenate((np.diag(d), [[0,0 ]]), axis=0)
D
# Out:
# array([[8.66918448, 0.        ],
#        [0.        , 4.10429538],
#        [0.        , 0.        ]])

# %%
np.dot(U, np.dot(D, vT))
# Out:
# array([[-1.,  2.],
#        [ 3., -2.],
#        [ 5.,  7.]])

# %%
P
# Out:
# tensor([[25.,  2., -5.],
#         [ 3., -2.,  1.],
#         [ 5.,  7.,  4.]])

# %%
U, S_vals, vT = torch.linalg.svd(P)
U, S_vals, vT
# Out:
# (tensor([[-0.9757, -0.1823, -0.1214],
#          [-0.0975, -0.1350,  0.9860],
#          [-0.1961,  0.9739,  0.1140]]),
#  tensor([26.1632,  8.1875,  2.5395]),
#  tensor([[-0.9810, -0.1196,  0.1528],
#          [-0.0113,  0.8211,  0.5706],
#          [ 0.1937, -0.5581,  0.8069]]))

# %%
P_PT = P @ P.T
P_PT
# Out:
# tensor([[654.,  66., 119.],
#         [ 66.,  14.,   5.],
#         [119.,   5.,  90.]])

# %%
PPT_eigen_values, PPT_eigen_vectors = torch.linalg.eig(P_PT)
PPT_eigen_values, PPT_eigen_vectors
# Out:
# (tensor([684.5149+0.j,  67.0359+0.j,   6.4492+0.j]),
#  tensor([[ 0.9757+0.j,  0.1823+0.j,  0.1214+0.j],
#          [ 0.0975+0.j,  0.1350+0.j, -0.9860+0.j],
#          [ 0.1961+0.j, -0.9739+0.j, -0.1140+0.j]]))

# %%
U
# Out:
# tensor([[-0.9757, -0.1823, -0.1214],
#         [-0.0975, -0.1350,  0.9860],
#         [-0.1961,  0.9739,  0.1140]])

# %%
torch.abs(PPT_eigen_vectors)
# Out:
# tensor([[0.9757, 0.1823, 0.1214],
#         [0.0975, 0.1350, 0.9860],
#         [0.1961, 0.9739, 0.1140]])

# %%
U = U.to(PPT_eigen_vectors.dtype)
U
# Out:
# tensor([[-0.9757+0.j, -0.1823+0.j, -0.1214+0.j],
#         [-0.0975+0.j, -0.1350+0.j,  0.9860+0.j],
#         [-0.1961+0.j,  0.9739+0.j,  0.1140+0.j]])

# %%
torch.allclose(U, PPT_eigen_vectors)
# Out:
# False

# %%
P
# Out:
# tensor([[25.,  2., -5.],
#         [ 3., -2.,  1.],
#         [ 5.,  7.,  4.]])

# %%
P_PT = P @ P.T
P_PT
# Out:
# tensor([[654.,  66., 119.],
#         [ 66.,  14.,   5.],
#         [119.,   5.,  90.]])

# %%
P_eigen_values, P_eigen_vectors = torch.linalg.eig(P_PT)
P_eigen_values.to(torch.float32), P_eigen_vectors.to(torch.float32)
# Out:
# C:\Users\archb\AppData\Local\Temp\ipykernel_50676\3957455496.py:2: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\Copy.cpp:308.)
#   P_eigen_values.to(torch.float32), P_eigen_vectors.to(torch.float32)
# (tensor([684.5149,  67.0359,   6.4492]),
#  tensor([[ 0.9757,  0.1823,  0.1214],
#          [ 0.0975,  0.1350, -0.9860],
#          [ 0.1961, -0.9739, -0.1140]]))

# %%
U, S_vals, vT = torch.linalg.svd(P)
U, S_vals, vT
# Out:
# (tensor([[-0.9757, -0.1823, -0.1214],
#          [-0.0975, -0.1350,  0.9860],
#          [-0.1961,  0.9739,  0.1140]]),
#  tensor([26.1632,  8.1875,  2.5395]),
#  tensor([[-0.9810, -0.1196,  0.1528],
#          [-0.0113,  0.8211,  0.5706],
#          [ 0.1937, -0.5581,  0.8069]]))

# %%
torch.abs(U)
# Out:
# tensor([[0.9757, 0.1823, 0.1214],
#         [0.0975, 0.1350, 0.9860],
#         [0.1961, 0.9739, 0.1140]])

# %%
torch.abs(PPT_eigen_vectors)
# Out:
# tensor([[0.9757, 0.1823, 0.1214],
#         [0.0975, 0.1350, 0.9860],
#         [0.1961, 0.9739, 0.1140]])

# %%
torch.allclose(torch.abs(U), torch.abs(PPT_eigen_vectors))
# Out:
# True

# %%
PT_P = P.T @ P
PT_P
# Out:
# tensor([[ 659.,   79., -102.],
#         [  79.,   57.,   16.],
#         [-102.,   16.,   42.]])

# %%
PT_P_eigen_values, PT_P_eigen_vectors = torch.linalg.eig(PT_P)
PT_P_eigen_values.to(torch.float32), PT_P_eigen_vectors.to(torch.float32)
# Out:
# (tensor([684.5149,   6.4492,  67.0359]),
#  tensor([[ 0.9810,  0.1937, -0.0113],
#          [ 0.1196, -0.5581,  0.8211],
#          [-0.1528,  0.8069,  0.5706]]))

# %%
torch.abs(vT)
# Out:
# tensor([[0.9810, 0.1196, 0.1528],
#         [0.0113, 0.8211, 0.5706],
#         [0.1937, 0.5581, 0.8069]])

# %%
torch.allclose(torch.abs(vT), torch.abs(PT_P_eigen_vectors))
# Out:
# False

# %%
S_vals
# Out:
# tensor([26.1632,  8.1875,  2.5395])

# %%
torch.sqrt(P_eigen_vectors)
# Out:
# tensor([[0.9878+0.0000j, 0.4269+0.0000j, 0.3485+0.0000j],
#         [0.3123+0.0000j, 0.3674+0.0000j, 0.0000+0.9930j],
#         [0.4429+0.0000j, 0.0000+0.9869j, 0.0000+0.3376j]])

# %%
A_p = torch.tensor([[-1, 2], [3, -2], [5,7.]])
A_p
# Out:
# tensor([[-1.,  2.],
#         [ 3., -2.],
#         [ 5.,  7.]])

# %%
torch.pinverse(A_p)
# Out:
# tensor([[-0.0877,  0.1777,  0.0758],
#         [ 0.0766, -0.1193,  0.0869]])

# %%
U, d, VT = torch.linalg.svd(A_p, full_matrices=False)
U, d, VT
# Out:
# (tensor([[ 0.1271,  0.4741],
#          [ 0.0016, -0.8785],
#          [ 0.9919, -0.0593]]),
#  tensor([8.6692, 4.1043]),
#  tensor([[ 0.5580,  0.8298],
#          [-0.8298,  0.5580]]))

# %%
Dinv = torch.linalg.inv(torch.diag(d))
Dinv
# Out:
# tensor([[0.1154, 0.0000],
#         [0.0000, 0.2436]])

# %%
sigma_plus = torch.diag(1/ d)
sigma_plus
# Out:
# tensor([[0.1154, 0.0000],
#         [0.0000, 0.2436]])

# %%
torch.pinverse(A_p)
# Out:
# tensor([[-0.0877,  0.1777,  0.0758],
#         [ 0.0766, -0.1193,  0.0869]])

# %%
A_p
# Out:
# tensor([[-1.,  2.],
#         [ 3., -2.],
#         [ 5.,  7.]])

# %%
torch.trace(A_p)
# Out:
# tensor(-3.)

# %%
torch.linalg.norm(A_p, ord='fro') # Frobenius norm
# Out:
# tensor(9.5917)

# %%
torch.linalg.norm(A_p) # Frobenius norm
# Out:
# tensor(9.5917)

# %%
torch.sqrt(torch.trace(A_p @ A_p.T))
# Out:
# tensor(9.5917)

# %%
import torch

# %%
x = torch.tensor([0, 1, 2, 3, 4, 5, 6, 7.])
x
# Out:
# tensor([0., 1., 2., 3., 4., 5., 6., 7.])

# %%
m = torch.tensor([0.7]).requires_grad_()
m
# Out:
# tensor([0.7000], requires_grad=True)

# %%
b = torch.tensor([0.007]).requires_grad_()
b
# Out:
# tensor([0.0070], requires_grad=True)

# %%
y = torch.tensor([1.86, 1.31, .62, .33, .09, -.67, -1.23, -1.37])   
y
# Out:
# tensor([ 1.8600,  1.3100,  0.6200,  0.3300,  0.0900, -0.6700, -1.2300, -1.3700])

# %%
def regression(my_x, my_m, my_b):
    return my_x * my_m + my_b

# %%
def mse_loss(pred, target):
    sigma = torch.sum((pred - target) ** 2)
    return sigma/ len(target)

# %%
cost = mse_loss(regression(x, m, b), y)
cost
# Out:
# tensor(980.0833, grad_fn=<DivBackward0>)

# %%
cost.backward()
m.grad, b.grad
# Out:
# (tensor([-260.7042]), tensor([-55.4474]))

# %%
optimizer = torch.optim.SGD([m, b], lr=0.01)
optimizer.step()

# %%
mse_loss(regression(x, m, b), y)
# Out:
# tensor(399.0400, grad_fn=<DivBackward0>)

# %%
epochs = 788 
for epoch in range(epochs):
    cost = mse_loss(regression(x, m, b), y)
    cost.backward()
    optimizer.step()
    optimizer.zero_grad()

    print(f"Epoch {epoch+1}: m={m.item()}, b={b.item()}, cost={cost.item()}")
# Out:
# Epoch 1: m=0.05405092239379883, b=-2.281059741973877, cost=399.0400390625
# Epoch 2: m=0.1537572741508484, b=-2.2368721961975098, cost=6.338708877563477
# Epoch 3: m=0.21547327935695648, b=-2.200547695159912, cost=5.356086254119873
# Epoch 4: m=0.2530459761619568, b=-2.1692698001861572, cost=4.926919937133789
# Epoch 5: m=0.275278776884079, b=-2.141247510910034, cost=4.721827983856201
# Epoch 6: m=0.28776854276657104, b=-2.115342140197754, cost=4.607670307159424
# Epoch 7: m=0.2940734922885895, b=-2.0908291339874268, cost=4.530627250671387
# Epoch 8: m=0.2964558005332947, b=-2.0672476291656494, cost=4.468941688537598
# Epoch 9: m=0.29635360836982727, b=-2.044304609298706, cost=4.413814544677734
# Epoch 10: m=0.2946811616420746, b=-2.021813154220581, cost=4.361685752868652
# Epoch 11: m=0.29201966524124146, b=-1.9996545314788818, cost=4.311110973358154
# Epoch 12: m=0.2887386083602905, b=-1.9777528047561646, cost=4.261504650115967
# Epoch 13: m=0.28507280349731445, b=-1.956059455871582, cost=4.212625026702881
# Epoch 14: m=0.2811715006828308, b=-1.9345433712005615, cost=4.164369583129883
# Epoch 15: m=0.27712950110435486, b=-1.9131845235824585, cost=4.116695404052734
# Epoch 16: m=0.2730070948600769, b=-1.891969919204712, cost=4.069579124450684
# Epoch 17: m=0.26884251832962036, b=-1.8708909749984741, cost=4.023008823394775
# Epoch 18: m=0.2646600008010864, b=-1.8499420881271362, cost=3.976975917816162
# Epoch 19: m=0.26047495007514954, b=-1.8291194438934326, cost=3.9314727783203125
# Epoch 20: m=0.2562970817089081, b=-1.8084203004837036, cost=3.8864927291870117
# Epoch 21: m=0.2521325349807739, b=-1.7878427505493164, cost=3.8420310020446777
# Epoch 22: m=0.2479851394891739, b=-1.7673851251602173, cost=3.7980799674987793
# Epoch 23: m=0.24385729432106018, b=-1.7470463514328003, cost=3.754633903503418
# Epoch 24: m=0.23975048959255219, b=-1.726825475692749, cost=3.7116875648498535
# Epoch 25: m=0.23566560447216034, b=-1.706721544265747, cost=3.6692352294921875
# Epoch 26: m=0.23160314559936523, b=-1.6867337226867676, cost=3.6272709369659424
# Epoch 27: m=0.22756341099739075, b=-1.6668612957000732, cost=3.585789680480957
# Epoch 28: m=0.22354650497436523, b=-1.6471035480499268, cost=3.5447847843170166
# Epoch 29: m=0.21955247223377228, b=-1.6274597644805908, cost=3.504251480102539
# Epoch 30: m=0.2155812829732895, b=-1.6079292297363281, cost=3.464184045791626
# Epoch 31: m=0.2116328775882721, b=-1.588511347770691, cost=3.4245777130126953
# Epoch 32: m=0.20770716667175293, b=-1.569205403327942, cost=3.3854260444641113
# Epoch 33: m=0.20380403101444244, b=-1.5500108003616333, cost=3.3467252254486084
# Epoch 34: m=0.19992338120937347, b=-1.5309268236160278, cost=3.308468818664551
# Epoch 35: m=0.19606506824493408, b=-1.5119528770446777, cost=3.2706527709960938
# Epoch 36: m=0.1922290027141571, b=-1.4930883646011353, cost=3.233271360397339
# Epoch 37: m=0.1884150356054306, b=-1.474332571029663, cost=3.196319103240967
# Epoch 38: m=0.18462304770946503, b=-1.455685019493103, cost=3.159791946411133
# Epoch 39: m=0.18085293471813202, b=-1.4371448755264282, cost=3.123685359954834
# Epoch 40: m=0.17710454761981964, b=-1.4187116622924805, cost=3.087993860244751
# Epoch 41: m=0.17337776720523834, b=-1.400384783744812, cost=3.052712917327881
# Epoch 42: m=0.16967248916625977, b=-1.3821635246276855, cost=3.017836809158325
# Epoch 43: m=0.16598856449127197, b=-1.3640472888946533, cost=2.9833624362945557
# Epoch 44: m=0.1623258739709854, b=-1.3460355997085571, cost=2.9492833614349365
# Epoch 45: m=0.15868431329727173, b=-1.3281277418136597, cost=2.915597677230835
# Epoch 46: m=0.15506374835968018, b=-1.3103231191635132, cost=2.882298469543457
# Epoch 47: m=0.1514640599489212, b=-1.29262113571167, cost=2.8493828773498535
# Epoch 48: m=0.14788511395454407, b=-1.2750211954116821, cost=2.8168447017669678
# Epoch 49: m=0.1443268060684204, b=-1.257522702217102, cost=2.7846808433532715
# Epoch 50: m=0.14078901708126068, b=-1.2401251792907715, cost=2.752887010574341
# Epoch 51: m=0.13727162778377533, b=-1.2228279113769531, cost=2.721458673477173
# Epoch 52: m=0.1337745040655136, b=-1.2056304216384888, cost=2.690392017364502
# Epoch 53: m=0.13029755651950836, b=-1.1885319948196411, cost=2.659682035446167
# Epoch 54: m=0.12684065103530884, b=-1.171532154083252, cost=2.6293256282806396
# Epoch 55: m=0.12340367585420609, b=-1.1546303033828735, cost=2.599318027496338
# Epoch 56: m=0.11998651176691055, b=-1.1378259658813477, cost=2.569655179977417
# Epoch 57: m=0.11658905446529388, b=-1.1211185455322266, cost=2.5403335094451904
# Epoch 58: m=0.11321118474006653, b=-1.1045074462890625, cost=2.5113492012023926
# Epoch 59: m=0.10985279083251953, b=-1.0879920721054077, cost=2.482698440551758
# Epoch 60: m=0.10651376098394394, b=-1.071571946144104, cost=2.454376459121704
# Epoch 61: m=0.1031939834356308, b=-1.0552464723587036, cost=2.4263803958892822
# Epoch 62: m=0.09989333897829056, b=-1.0390151739120483, cost=2.3987059593200684
# Epoch 63: m=0.09661173075437546, b=-1.0228774547576904, cost=2.371350049972534
# Epoch 64: m=0.09334904700517654, b=-1.0068327188491821, cost=2.344308614730835
# Epoch 65: m=0.09010516852140427, b=-0.9908804893493652, cost=2.3175785541534424
# Epoch 66: m=0.08687999099493027, b=-0.9750202298164368, cost=2.2911550998687744
# Epoch 67: m=0.08367341011762619, b=-0.9592514038085938, cost=2.265035390853882
# Epoch 68: m=0.08048531413078308, b=-0.943573534488678, cost=2.2392163276672363
# Epoch 69: m=0.07731559872627258, b=-0.9279860258102417, cost=2.2136943340301514
# Epoch 70: m=0.07416415959596634, b=-0.9124884009361267, cost=2.1884653568267822
# Epoch 71: m=0.07103089243173599, b=-0.89708012342453, cost=2.163527011871338
# Epoch 72: m=0.06791568547487259, b=-0.8817606568336487, cost=2.1388750076293945
# Epoch 73: m=0.06481844186782837, b=-0.8665295243263245, cost=2.114506244659424
# Epoch 74: m=0.06173905357718468, b=-0.8513862490653992, cost=2.0904181003570557
# Epoch 75: m=0.05867742374539375, b=-0.836330235004425, cost=2.0666065216064453
# Epoch 76: m=0.05563344061374664, b=-0.8213610649108887, cost=2.0430691242218018
# Epoch 77: m=0.052607011049985886, b=-0.8064782023429871, cost=2.0198020935058594
# Epoch 78: m=0.049598030745983124, b=-0.7916811108589172, cost=1.9968026876449585
# Epoch 79: m=0.0466063991189003, b=-0.7769693732261658, cost=1.9740676879882812
# Epoch 80: m=0.04363201558589935, b=-0.7623424530029297, cost=1.9515938758850098
# Epoch 81: m=0.040674783289432526, b=-0.7477998733520508, cost=1.9293789863586426
# Epoch 82: m=0.03773459792137146, b=-0.7333410978317261, cost=1.9074193239212036
# Epoch 83: m=0.034811366349458694, b=-0.7189657092094421, cost=1.8857117891311646
# Epoch 84: m=0.03190498799085617, b=-0.704673171043396, cost=1.8642542362213135
# Epoch 85: m=0.02901536412537098, b=-0.6904630661010742, cost=1.8430429697036743
# Epoch 86: m=0.02614240162074566, b=-0.6763348579406738, cost=1.8220759630203247
# Epoch 87: m=0.023285998031497, b=-0.6622881293296814, cost=1.8013499975204468
# Epoch 88: m=0.020446065813302994, b=-0.6483224034309387, cost=1.7808622121810913
# Epoch 89: m=0.017622511833906174, b=-0.6344372034072876, cost=1.7606101036071777
# Epoch 90: m=0.014815235510468483, b=-0.6206320524215698, cost=1.7405908107757568
# Epoch 91: m=0.01202414557337761, b=-0.6069064736366272, cost=1.720801591873169
# Epoch 92: m=0.009249147959053516, b=-0.5932600498199463, cost=1.7012401819229126
# Epoch 93: m=0.0064901504665613174, b=-0.5796923041343689, cost=1.68190336227417
# Epoch 94: m=0.003747056471183896, b=-0.5662027597427368, cost=1.662788987159729
# Epoch 95: m=0.001019779359921813, b=-0.5527909994125366, cost=1.6438943147659302
# Epoch 96: m=-0.0016917753964662552, b=-0.5394565463066101, cost=1.625217080116272
# Epoch 97: m=-0.004387697204947472, b=-0.5261989831924438, cost=1.6067545413970947
# Epoch 98: m=-0.007068075239658356, b=-0.5130178928375244, cost=1.5885043144226074
# Epoch 99: m=-0.009732995182275772, b=-0.4999127686023712, cost=1.5704635381698608
# Epoch 100: m=-0.01238255575299263, b=-0.4868831932544708, cost=1.5526307821273804
# Epoch 101: m=-0.015016837976872921, b=-0.4739287495613098, cost=1.535002589225769
# Epoch 102: m=-0.017635934054851532, b=-0.46104899048805237, cost=1.5175774097442627
# Epoch 103: m=-0.020239926874637604, b=-0.44824349880218506, cost=1.5003522634506226
# Epoch 104: m=-0.022828904911875725, b=-0.43551182746887207, cost=1.483325481414795
# Epoch 105: m=-0.025402963161468506, b=-0.4228535592556, cost=1.466494083404541
# Epoch 106: m=-0.027962176129221916, b=-0.41026827692985535, cost=1.4498567581176758
# Epoch 107: m=-0.030506636947393417, b=-0.39775556325912476, cost=1.4334102869033813
# Epoch 108: m=-0.03303642198443413, b=-0.3853150010108948, cost=1.4171528816223145
# Epoch 109: m=-0.03555162623524666, b=-0.3729461431503296, cost=1.401082992553711
# Epoch 110: m=-0.03805232793092728, b=-0.36064860224723816, cost=1.3851972818374634
# Epoch 111: m=-0.04053860902786255, b=-0.34842196106910706, cost=1.369494080543518
# Epoch 112: m=-0.04301055893301964, b=-0.33626583218574524, cost=1.3539718389511108
# Epoch 113: m=-0.04546825587749481, b=-0.3241797685623169, cost=1.3386279344558716
# Epoch 114: m=-0.04791178181767464, b=-0.312163382768631, cost=1.323460578918457
# Epoch 115: m=-0.05034122243523598, b=-0.30021628737449646, cost=1.3084675073623657
# Epoch 116: m=-0.0527566559612751, b=-0.2883380651473999, cost=1.293647050857544
# Epoch 117: m=-0.055158164352178574, b=-0.27652832865715027, cost=1.2789965867996216
# Epoch 118: m=-0.057545825839042664, b=-0.2647866904735565, cost=1.2645145654678345
# Epoch 119: m=-0.05991971865296364, b=-0.2531127631664276, cost=1.2501994371414185
# Epoch 120: m=-0.062279924750328064, b=-0.24150612950325012, cost=1.2360488176345825
# Epoch 121: m=-0.06462652236223221, b=-0.2299664169549942, cost=1.2220607995986938
# Epoch 122: m=-0.06695958971977234, b=-0.2184932380914688, cost=1.2082335948944092
# Epoch 123: m=-0.06927920877933502, b=-0.2070862054824829, cost=1.1945654153823853
# Epoch 124: m=-0.07158545404672623, b=-0.19574493169784546, cost=1.1810542345046997
# Epoch 125: m=-0.07387840002775192, b=-0.1844690442085266, cost=1.1676985025405884
# Epoch 126: m=-0.07615812867879868, b=-0.17325817048549652, cost=1.154496431350708
# Epoch 127: m=-0.07842471450567245, b=-0.16211193799972534, cost=1.1414462327957153
# Epoch 128: m=-0.08067823201417923, b=-0.15102997422218323, cost=1.1285456418991089
# Epoch 129: m=-0.08291874825954437, b=-0.14001190662384033, cost=1.1157938241958618
# Epoch 130: m=-0.08514635264873505, b=-0.1290573626756668, cost=1.1031887531280518
# Epoch 131: m=-0.08736111223697662, b=-0.11816596984863281, cost=1.0907281637191772
# Epoch 132: m=-0.08956310153007507, b=-0.10733737051486969, cost=1.0784109830856323
# Epoch 133: m=-0.09175240248441696, b=-0.09657120704650879, cost=1.0662354230880737
# Epoch 134: m=-0.09392907470464706, b=-0.08586711436510086, cost=1.0541998147964478
# Epoch 135: m=-0.09609320014715195, b=-0.07522473484277725, cost=1.0423027276992798
# Epoch 136: m=-0.09824484586715698, b=-0.06464371830224991, cost=1.0305423736572266
# Epoch 137: m=-0.10038408637046814, b=-0.05412370711565018, cost=1.018917202949524
# Epoch 138: m=-0.10251099616289139, b=-0.043664347380399704, cost=1.0074257850646973
# Epoch 139: m=-0.1046256422996521, b=-0.033265288919210434, cost=0.9960664510726929
# Epoch 140: m=-0.10672809928655624, b=-0.02292618900537491, cost=0.9848376512527466
# Epoch 141: m=-0.1088184267282486, b=-0.012646699324250221, cost=0.9737379550933838
# Epoch 142: m=-0.11089670658111572, b=-0.0024264762178063393, cost=0.9627659320831299
# Epoch 143: m=-0.112963005900383, b=0.007734822109341621, cost=0.9519201517105103
# Epoch 144: m=-0.11501739174127579, b=0.017837535589933395, cost=0.9411989450454712
# Epoch 145: m=-0.11705993115901947, b=0.027882002294063568, cost=0.9306010007858276
# Epoch 146: m=-0.11909069120883942, b=0.03786855936050415, cost=0.9201250672340393
# Epoch 147: m=-0.1211097463965416, b=0.047797538340091705, cost=0.9097694754600525
# Epoch 148: m=-0.12311716377735138, b=0.0576692670583725, cost=0.8995329737663269
# Epoch 149: m=-0.12511301040649414, b=0.06748408079147339, cost=0.8894141316413879
# Epoch 150: m=-0.12709733843803406, b=0.07724230736494064, cost=0.8794116377830505
# Epoch 151: m=-0.1290702372789383, b=0.08694427460432053, cost=0.8695241808891296
# Epoch 152: m=-0.13103175163269043, b=0.0965903028845787, cost=0.8597503900527954
# Epoch 153: m=-0.13298195600509644, b=0.10618072003126144, cost=0.850088894367218
# Epoch 154: m=-0.13492092490196228, b=0.11571583896875381, cost=0.8405386209487915
# Epoch 155: m=-0.13684871792793274, b=0.12519598007202148, cost=0.8310981392860413
# Epoch 156: m=-0.1387653797864914, b=0.13462147116661072, cost=0.8217661380767822
# Epoch 157: m=-0.1406709998846054, b=0.143992617726326, cost=0.8125414848327637
# Epoch 158: m=-0.14256563782691956, b=0.15330973267555237, cost=0.8034228086471558
# Epoch 159: m=-0.1444493532180786, b=0.16257312893867493, cost=0.7944090962409973
# Epoch 160: m=-0.14632220566272736, b=0.17178311944007874, cost=0.7854989171028137
# Epoch 161: m=-0.14818425476551056, b=0.18094001710414886, cost=0.7766912579536438
# Epoch 162: m=-0.1500355750322342, b=0.1900441199541092, cost=0.7679847478866577
# Epoch 163: m=-0.15187621116638184, b=0.1990957260131836, cost=0.7593785524368286
# Epoch 164: m=-0.15370623767375946, b=0.20809514820575714, cost=0.7508711218833923
# Epoch 165: m=-0.15552571415901184, b=0.2170426845550537, cost=0.7424615621566772
# Epoch 166: m=-0.15733470022678375, b=0.22593863308429718, cost=0.7341488003730774
# Epoch 167: m=-0.15913325548171997, b=0.23478329181671143, cost=0.7259314656257629
# Epoch 168: m=-0.16092143952846527, b=0.24357695877552032, cost=0.7178087830543518
# Epoch 169: m=-0.16269932687282562, b=0.25231993198394775, cost=0.7097792029380798
# Epoch 170: m=-0.1644669622182846, b=0.2610124945640564, cost=0.7018422484397888
# Epoch 171: m=-0.166224405169487, b=0.26965492963790894, cost=0.6939964294433594
# Epoch 172: m=-0.16797171533107758, b=0.27824753522872925, cost=0.6862407326698303
# Epoch 173: m=-0.1697089523077011, b=0.2867906093597412, cost=0.6785743236541748
# Epoch 174: m=-0.1714361608028412, b=0.2952844202518463, cost=0.6709959506988525
# Epoch 175: m=-0.17315341532230377, b=0.30372926592826843, cost=0.6635048985481262
# Epoch 176: m=-0.17486077547073364, b=0.31212541460990906, cost=0.656099796295166
# Epoch 177: m=-0.17655828595161438, b=0.32047316431999207, cost=0.6487799882888794
# Epoch 178: m=-0.17824600636959076, b=0.32877278327941895, cost=0.6415441632270813
# Epoch 179: m=-0.17992399632930756, b=0.3370245397090912, cost=0.634391725063324
# Epoch 180: m=-0.18159231543540955, b=0.34522873163223267, cost=0.6273213624954224
# Epoch 181: m=-0.1832510232925415, b=0.3533856272697449, cost=0.6203323602676392
# Epoch 182: m=-0.184900164604187, b=0.3614954948425293, cost=0.6134238839149475
# Epoch 183: m=-0.18653979897499084, b=0.3695586025714874, cost=0.6065945625305176
# Epoch 184: m=-0.18816997110843658, b=0.37757521867752075, cost=0.5998439192771912
# Epoch 185: m=-0.189790740609169, b=0.38554561138153076, cost=0.5931708216667175
# Epoch 186: m=-0.19140218198299408, b=0.39347004890441895, cost=0.5865744352340698
# Epoch 187: m=-0.1930043250322342, b=0.4013487994670868, cost=0.5800539255142212
# Epoch 188: m=-0.19459722936153412, b=0.4091821312904358, cost=0.5736083984375
# Epoch 189: m=-0.19618095457553864, b=0.41697028279304504, cost=0.5672370195388794
# Epoch 190: m=-0.19775554537773132, b=0.4247135519981384, cost=0.5609389543533325
# Epoch 191: m=-0.19932106137275696, b=0.43241217732429504, cost=0.5547131299972534
# Epoch 192: m=-0.20087754726409912, b=0.440066397190094, cost=0.5485589504241943
# Epoch 193: m=-0.2024250477552414, b=0.44767650961875916, cost=0.5424755215644836
# Epoch 194: m=-0.20396363735198975, b=0.45524272322654724, cost=0.536462128162384
# Epoch 195: m=-0.20549336075782776, b=0.46276533603668213, cost=0.5305178761482239
# Epoch 196: m=-0.207014262676239, b=0.47024455666542053, cost=0.5246418118476868
# Epoch 197: m=-0.2085263878107071, b=0.47768065333366394, cost=0.5188334584236145
# Epoch 198: m=-0.21002979576587677, b=0.48507389426231384, cost=0.5130918622016907
# Epoch 199: m=-0.21152454614639282, b=0.49242448806762695, cost=0.5074162483215332
# Epoch 200: m=-0.21301066875457764, b=0.49973270297050476, cost=0.5018059015274048
# Epoch 201: m=-0.214488223195076, b=0.5069987773895264, cost=0.49626001715660095
# Epoch 202: m=-0.21595725417137146, b=0.5142229795455933, cost=0.49077799916267395
# Epoch 203: m=-0.21741782128810883, b=0.5214055180549622, cost=0.48535892367362976
# Epoch 204: m=-0.21886996924877167, b=0.5285466313362122, cost=0.48000216484069824
# Epoch 205: m=-0.22031374275684357, b=0.5356466174125671, cost=0.4747070372104645
# Epoch 206: m=-0.2217492014169693, b=0.5427056550979614, cost=0.46947285532951355
# Epoch 207: m=-0.22317637503147125, b=0.5497239828109741, cost=0.46429866552352905
# Epoch 208: m=-0.2245953232049942, b=0.5567018389701843, cost=0.45918408036231995
# Epoch 209: m=-0.22600609064102173, b=0.5636394619941711, cost=0.45412835478782654
# Epoch 210: m=-0.22740872204303741, b=0.5705370903015137, cost=0.44913068413734436
# Epoch 211: m=-0.22880326211452484, b=0.577394962310791, cost=0.44419050216674805
# Epoch 212: m=-0.23018977046012878, b=0.5842133164405823, cost=0.4393070936203003
# Epoch 213: m=-0.23156827688217163, b=0.5909923315048218, cost=0.43447986245155334
# Epoch 214: m=-0.23293884098529816, b=0.5977322459220886, cost=0.4297080934047699
# Epoch 215: m=-0.23430150747299194, b=0.6044332981109619, cost=0.424991250038147
# Epoch 216: m=-0.23565630614757538, b=0.6110957264900208, cost=0.4203285574913025
# Epoch 217: m=-0.23700329661369324, b=0.6177197694778442, cost=0.41571953892707825
# Epoch 218: m=-0.2383425235748291, b=0.6243056058883667, cost=0.41116347908973694
# Epoch 219: m=-0.23967403173446655, b=0.6308534741401672, cost=0.4066598415374756
# Epoch 220: m=-0.24099786579608917, b=0.637363612651825, cost=0.40220797061920166
# Epoch 221: m=-0.24231407046318054, b=0.6438362002372742, cost=0.3978073298931122
# Epoch 222: m=-0.24362267553806305, b=0.650271475315094, cost=0.39345720410346985
# Epoch 223: m=-0.24492374062538147, b=0.6566696166992188, cost=0.3891570568084717
# Epoch 224: m=-0.24621731042861938, b=0.6630308628082275, cost=0.38490647077560425
# Epoch 225: m=-0.24750341475009918, b=0.6693554520606995, cost=0.38070473074913025
# Epoch 226: m=-0.24878209829330444, b=0.6756435632705688, cost=0.37655124068260193
# Epoch 227: m=-0.25005340576171875, b=0.6818954348564148, cost=0.37244564294815063
# Epoch 228: m=-0.2513173818588257, b=0.6881112456321716, cost=0.3683871626853943
# Epoch 229: m=-0.25257408618927, b=0.6942912340164185, cost=0.36437538266181946
# Epoch 230: m=-0.25382354855537415, b=0.7004355788230896, cost=0.3604096472263336
# Epoch 231: m=-0.25506579875946045, b=0.7065445184707642, cost=0.3564895987510681
# Epoch 232: m=-0.2563008964061737, b=0.7126182317733765, cost=0.35261449217796326
# Epoch 233: m=-0.2575288712978363, b=0.7186569571495056, cost=0.34878405928611755
# Epoch 234: m=-0.25874975323677063, b=0.7246608138084412, cost=0.3449976444244385
# Epoch 235: m=-0.25996360182762146, b=0.730630099773407, cost=0.3412547707557678
# Epoch 236: m=-0.2611704468727112, b=0.7365649342536926, cost=0.33755484223365784
# Epoch 237: m=-0.26237034797668457, b=0.7424655556678772, cost=0.33389756083488464
# Epoch 238: m=-0.2635633051395416, b=0.748332142829895, cost=0.3302822411060333
# Epoch 239: m=-0.2647494077682495, b=0.7541649341583252, cost=0.3267086148262024
# Epoch 240: m=-0.2659286558628082, b=0.759964108467102, cost=0.32317596673965454
# Epoch 241: m=-0.26710110902786255, b=0.7657298445701599, cost=0.3196839988231659
# Epoch 242: m=-0.26826679706573486, b=0.7714623212814331, cost=0.3162321448326111
# Epoch 243: m=-0.26942577958106995, b=0.7771617770195007, cost=0.3128199875354767
# Epoch 244: m=-0.2705780863761902, b=0.7828283309936523, cost=0.3094470500946045
# Epoch 245: m=-0.27172374725341797, b=0.788462221622467, cost=0.3061129152774811
# Epoch 246: m=-0.2728627920150757, b=0.7940636277198792, cost=0.30281710624694824
# Epoch 247: m=-0.2739952802658081, b=0.799632728099823, cost=0.29955917596817017
# Epoch 248: m=-0.27512121200561523, b=0.8051697611808777, cost=0.2963387668132782
# Epoch 249: m=-0.27624067664146423, b=0.8106748461723328, cost=0.29315534234046936
# Epoch 250: m=-0.2773536741733551, b=0.8161482214927673, cost=0.2900085151195526
# Epoch 251: m=-0.2784602642059326, b=0.821590006351471, cost=0.28689783811569214
# Epoch 252: m=-0.27956047654151917, b=0.8270004391670227, cost=0.2838229537010193
# Epoch 253: m=-0.28065434098243713, b=0.8323796391487122, cost=0.28078344464302063
# Epoch 254: m=-0.2817418873310089, b=0.8377278447151184, cost=0.27777889370918274
# Epoch 255: m=-0.2828231751918793, b=0.8430452346801758, cost=0.2748088538646698
# Epoch 256: m=-0.2838982343673706, b=0.8483319282531738, cost=0.27187299728393555
# Epoch 257: m=-0.2849670946598053, b=0.8535881638526917, cost=0.26897087693214417
# Epoch 258: m=-0.28602978587150574, b=0.8588141202926636, cost=0.2661021053791046
# Epoch 259: m=-0.2870863378047943, b=0.8640099167823792, cost=0.26326635479927063
# Epoch 260: m=-0.2881368100643158, b=0.8691757917404175, cost=0.2604632079601288
# Epoch 261: m=-0.2891812324523926, b=0.8743118643760681, cost=0.25769221782684326
# Epoch 262: m=-0.29021963477134705, b=0.8794183135032654, cost=0.25495317578315735
# Epoch 263: m=-0.2912520468235016, b=0.8844953179359436, cost=0.25224554538726807
# Epoch 264: m=-0.2922784984111786, b=0.8895430564880371, cost=0.2495691329240799
# Epoch 265: m=-0.2932990491390228, b=0.8945617079734802, cost=0.24692346155643463
# Epoch 266: m=-0.2943136990070343, b=0.8995513916015625, cost=0.24430815875530243
# Epoch 267: m=-0.2953225076198578, b=0.904512345790863, cost=0.241722971200943
# Epoch 268: m=-0.2963255047798157, b=0.9094446897506714, cost=0.23916751146316528
# Epoch 269: m=-0.29732272028923035, b=0.9143486022949219, cost=0.23664145171642303
# Epoch 270: m=-0.2983141839504242, b=0.919224202632904, cost=0.23414437472820282
# Epoch 271: m=-0.2992999255657196, b=0.924071729183197, cost=0.23167605698108673
# Epoch 272: m=-0.30027997493743896, b=0.9288913011550903, cost=0.22923609614372253
# Epoch 273: m=-0.30125439167022705, b=0.9336830973625183, cost=0.22682420909404755
# Epoch 274: m=-0.30222317576408386, b=0.9384472370147705, cost=0.22444002330303192
# Epoch 275: m=-0.3031863868236542, b=0.9431838989257812, cost=0.22208330035209656
# Epoch 276: m=-0.304144024848938, b=0.9478932619094849, cost=0.21975365281105042
# Epoch 277: m=-0.3050961494445801, b=0.9525755047798157, cost=0.21745078265666962
# Epoch 278: m=-0.30604279041290283, b=0.9572307467460632, cost=0.2151743620634079
# Epoch 279: m=-0.30698397755622864, b=0.9618591070175171, cost=0.21292415261268616
# Epoch 280: m=-0.3079197108745575, b=0.9664608240127563, cost=0.21069981157779694
# Epoch 281: m=-0.30885007977485657, b=0.9710359573364258, cost=0.20850104093551636
# Epoch 282: m=-0.30977505445480347, b=0.9755847454071045, cost=0.20632757246494293
# Epoch 283: m=-0.31069472432136536, b=0.980107307434082, cost=0.2041790634393692
# Epoch 284: m=-0.31160908937454224, b=0.984603762626648, cost=0.20205527544021606
# Epoch 285: m=-0.3125181794166565, b=0.9890743494033813, cost=0.19995592534542084
# Epoch 286: m=-0.3134220242500305, b=0.993519127368927, cost=0.19788068532943726
# Epoch 287: m=-0.3143206536769867, b=0.9979382753372192, cost=0.19582931697368622
# Epoch 288: m=-0.3152140974998474, b=1.0023319721221924, cost=0.19380152225494385
# Epoch 289: m=-0.31610241532325745, b=1.0067002773284912, cost=0.19179704785346985
# Epoch 290: m=-0.3169855773448944, b=1.0110434293746948, cost=0.18981564044952393
# Epoch 291: m=-0.31786367297172546, b=1.0153615474700928, cost=0.1878570020198822
# Epoch 292: m=-0.3187367022037506, b=1.0196547508239746, cost=0.18592089414596558
# Epoch 293: m=-0.31960469484329224, b=1.0239232778549194, cost=0.18400700390338898
# Epoch 294: m=-0.32046768069267273, b=1.0281671285629272, cost=0.18211515247821808
# Epoch 295: m=-0.3213256895542145, b=1.0323865413665771, cost=0.180245041847229
# Epoch 296: m=-0.32217875123023987, b=1.0365816354751587, cost=0.17839641869068146
# Epoch 297: m=-0.3230268955230713, b=1.0407525300979614, cost=0.17656908929347992
# Epoch 298: m=-0.32387015223503113, b=1.044899344444275, cost=0.17476272583007812
# Epoch 299: m=-0.3247085511684418, b=1.0490223169326782, cost=0.17297716438770294
# Epoch 300: m=-0.3255421221256256, b=1.0531214475631714, cost=0.1712120771408081
# Epoch 301: m=-0.32637089490890503, b=1.0571969747543335, cost=0.16946735978126526
# Epoch 302: m=-0.32719486951828003, b=1.061249017715454, cost=0.16774269938468933
# Epoch 303: m=-0.3280141055583954, b=1.0652776956558228, cost=0.16603782773017883
# Epoch 304: m=-0.3288286030292511, b=1.069283127784729, cost=0.16435256600379944
# Epoch 305: m=-0.32963842153549194, b=1.0732654333114624, cost=0.16268670558929443
# Epoch 306: m=-0.3304435610771179, b=1.077224850654602, cost=0.16103999316692352
# Epoch 307: m=-0.3312440514564514, b=1.081161379814148, cost=0.1594121903181076
# Epoch 308: m=-0.3320399224758148, b=1.0850752592086792, cost=0.15780313313007355
# Epoch 309: m=-0.3328312039375305, b=1.0889666080474854, cost=0.15621253848075867
# Epoch 310: m=-0.3336179554462433, b=1.0928354263305664, cost=0.15464024245738983
# Epoch 311: m=-0.33440014719963074, b=1.0966819524765015, cost=0.15308602154254913
# Epoch 312: m=-0.33517783880233765, b=1.10050630569458, cost=0.15154972672462463
# Epoch 313: m=-0.335951030254364, b=1.1043086051940918, cost=0.15003105998039246
# Epoch 314: m=-0.3367197811603546, b=1.1080889701843262, cost=0.14852984249591827
# Epoch 315: m=-0.33748409152030945, b=1.1118475198745728, cost=0.14704591035842896
# Epoch 316: m=-0.3382439911365509, b=1.1155844926834106, cost=0.14557906985282898
# Epoch 317: m=-0.33899950981140137, b=1.1192998886108398, cost=0.14412900805473328
# Epoch 318: m=-0.3397506773471832, b=1.12299382686615, cost=0.14269565045833588
# Epoch 319: m=-0.34049752354621887, b=1.12666654586792, cost=0.14127880334854126
# Epoch 320: m=-0.3412400484085083, b=1.13031804561615, cost=0.13987819850444794
# Epoch 321: m=-0.3419782817363739, b=1.1339484453201294, cost=0.13849373161792755
# Epoch 322: m=-0.34271228313446045, b=1.1375579833984375, cost=0.13712520897388458
# Epoch 323: m=-0.34344205260276794, b=1.1411466598510742, cost=0.13577236235141754
# Epoch 324: m=-0.3441675901412964, b=1.1447147130966187, cost=0.13443513214588165
# Epoch 325: m=-0.34488895535469055, b=1.1482621431350708, cost=0.13311320543289185
# Epoch 326: m=-0.3456061780452728, b=1.1517890691757202, cost=0.13180650770664215
# Epoch 327: m=-0.3463192582130432, b=1.155295729637146, cost=0.13051486015319824
# Epoch 328: m=-0.3470282256603241, b=1.1587821245193481, cost=0.12923802435398102
# Epoch 329: m=-0.34773311018943787, b=1.1622484922409058, cost=0.1279759407043457
# Epoch 330: m=-0.3484339118003845, b=1.1656948328018188, cost=0.12672828137874603
# Epoch 331: m=-0.34913069009780884, b=1.169121265411377, cost=0.1254950314760208
# Epoch 332: m=-0.3498234450817108, b=1.1725280284881592, cost=0.12427592277526855
# Epoch 333: m=-0.35051220655441284, b=1.1759151220321655, cost=0.1230708435177803
# Epoch 334: m=-0.3511970043182373, b=1.1792826652526855, cost=0.12187961488962173
# Epoch 335: m=-0.3518778383731842, b=1.1826307773590088, cost=0.12070208042860031
# Epoch 336: m=-0.3525547385215759, b=1.1859595775604248, cost=0.1195380836725235
# Epoch 337: m=-0.35322776436805725, b=1.1892691850662231, cost=0.11838750541210175
# Epoch 338: m=-0.3538968861103058, b=1.1925597190856934, cost=0.11725012958049774
# Epoch 339: m=-0.3545621633529663, b=1.195831298828125, cost=0.11612582951784134
# Epoch 340: m=-0.3552235960960388, b=1.1990840435028076, cost=0.1150144636631012
# Epoch 341: m=-0.3558812141418457, b=1.2023180723190308, cost=0.11391586065292358
# Epoch 342: m=-0.35653504729270935, b=1.2055333852767944, cost=0.11282987892627716
# Epoch 343: m=-0.35718512535095215, b=1.2087302207946777, cost=0.11175642162561417
# Epoch 344: m=-0.3578314483165741, b=1.2119085788726807, cost=0.1106952577829361
# Epoch 345: m=-0.3584740459918976, b=1.2150685787200928, cost=0.10964632034301758
# Epoch 346: m=-0.3591129183769226, b=1.2182103395462036, cost=0.10860945284366608
# Epoch 347: m=-0.35974812507629395, b=1.2213339805603027, cost=0.10758452862501144
# Epoch 348: m=-0.3603796660900116, b=1.2244396209716797, cost=0.10657137632369995
# Epoch 349: m=-0.36100757122039795, b=1.227527379989624, cost=0.10556986927986145
# Epoch 350: m=-0.361631840467453, b=1.2305973768234253, cost=0.1045798733830452
# Epoch 351: m=-0.36225250363349915, b=1.2336496114730835, cost=0.10360125452280045
# Epoch 352: m=-0.36286959052085876, b=1.2366843223571777, cost=0.10263388603925705
# Epoch 353: m=-0.36348313093185425, b=1.239701509475708, cost=0.10167764127254486
# Epoch 354: m=-0.364093154668808, b=1.2427012920379639, cost=0.10073239356279373
# Epoch 355: m=-0.3646996319293976, b=1.2456837892532349, cost=0.09979800134897232
# Epoch 356: m=-0.3653026223182678, b=1.2486491203308105, cost=0.09887435287237167
# Epoch 357: m=-0.3659021556377411, b=1.251597285270691, cost=0.09796132892370224
# Epoch 358: m=-0.366498202085495, b=1.254528522491455, cost=0.09705883264541626
# Epoch 359: m=-0.3670908212661743, b=1.257442831993103, cost=0.09616667032241821
# Epoch 360: m=-0.36768004298210144, b=1.2603403329849243, cost=0.09528478235006332
# Epoch 361: m=-0.36826586723327637, b=1.2632211446762085, cost=0.09441302716732025
# Epoch 362: m=-0.3688482940196991, b=1.2660853862762451, cost=0.09355130791664124
# Epoch 363: m=-0.3694273829460144, b=1.2689330577850342, cost=0.09269947558641434
# Epoch 364: m=-0.3700031042098999, b=1.2717642784118652, cost=0.0918574407696724
# Epoch 365: m=-0.37057551741600037, b=1.2745791673660278, cost=0.09102512151002884
# Epoch 366: m=-0.3711446225643158, b=1.2773778438568115, cost=0.09020236134529114
# Epoch 367: m=-0.3717104494571686, b=1.2801604270935059, cost=0.08938905596733093
# Epoch 368: m=-0.3722730278968811, b=1.2829269170761108, cost=0.08858509361743927
# Epoch 369: m=-0.37283235788345337, b=1.285677433013916, cost=0.08779037743806839
# Epoch 370: m=-0.3733884394168854, b=1.288412094116211, cost=0.08700481057167053
# Epoch 371: m=-0.3739413321018219, b=1.2911310195922852, cost=0.08622828871011734
# Epoch 372: m=-0.37449103593826294, b=1.2938343286514282, cost=0.08546067774295807
# Epoch 373: m=-0.3750375807285309, b=1.2965220212936401, cost=0.08470185846090317
# Epoch 374: m=-0.37558096647262573, b=1.2991942167282104, cost=0.08395180106163025
# Epoch 375: m=-0.3761212229728699, b=1.3018510341644287, cost=0.08321036398410797
# Epoch 376: m=-0.3766583800315857, b=1.304492473602295, cost=0.08247743546962738
# Epoch 377: m=-0.3771924376487732, b=1.3071186542510986, cost=0.08175294101238251
# Epoch 378: m=-0.3777233958244324, b=1.3097296953201294, cost=0.08103680610656738
# Epoch 379: m=-0.3782512843608856, b=1.3123257160186768, cost=0.08032888919115067
# Epoch 380: m=-0.3787761330604553, b=1.3149068355560303, cost=0.07962910085916519
# Epoch 381: m=-0.37929797172546387, b=1.31747305393219, cost=0.0789373442530632
# Epoch 382: m=-0.37981680035591125, b=1.3200244903564453, cost=0.07825355231761932
# Epoch 383: m=-0.3803326189517975, b=1.3225611448287964, cost=0.0775776132941246
# Epoch 384: m=-0.38084548711776733, b=1.3250832557678223, cost=0.07690947502851486
# Epoch 385: m=-0.3813554048538208, b=1.327590823173523, cost=0.07624899595975876
# Epoch 386: m=-0.3818623721599579, b=1.3300838470458984, cost=0.07559609413146973
# Epoch 387: m=-0.382366418838501, b=1.3325625658035278, cost=0.07495073974132538
# Epoch 388: m=-0.3828675448894501, b=1.3350269794464111, cost=0.07431276887655258
# Epoch 389: m=-0.38336578011512756, b=1.337477207183838, cost=0.07368215918540955
# Epoch 390: m=-0.38386115431785583, b=1.339913249015808, cost=0.07305876910686493
# Epoch 391: m=-0.3843536674976349, b=1.3423352241516113, cost=0.07244259119033813
# Epoch 392: m=-0.3848433494567871, b=1.344743251800537, cost=0.07183348387479782
# Epoch 393: m=-0.3853302001953125, b=1.347137451171875, cost=0.07123138010501862
# Epoch 394: m=-0.38581424951553345, b=1.349517822265625, cost=0.07063618302345276
# Epoch 395: m=-0.38629549741744995, b=1.3518844842910767, cost=0.07004783302545547
# Epoch 396: m=-0.3867740035057068, b=1.35423743724823, cost=0.0694662556052208
# Epoch 397: m=-0.38724973797798157, b=1.356576919555664, cost=0.06889137625694275
# Epoch 398: m=-0.3877227008342743, b=1.3589028120040894, cost=0.06832307577133179
# Epoch 399: m=-0.38819295167922974, b=1.361215353012085, cost=0.06776135414838791
# Epoch 400: m=-0.3886604905128479, b=1.3635145425796509, cost=0.06720605492591858
# Epoch 401: m=-0.38912534713745117, b=1.3658004999160767, cost=0.066657155752182
# Epoch 402: m=-0.38958752155303955, b=1.3680732250213623, cost=0.06611455976963043
# Epoch 403: m=-0.39004701375961304, b=1.3703328371047974, cost=0.06557820737361908
# Epoch 404: m=-0.390503853559494, b=1.3725794553756714, cost=0.06504803895950317
# Epoch 405: m=-0.3909580707550049, b=1.3748130798339844, cost=0.06452395021915436
# Epoch 406: m=-0.39140966534614563, b=1.3770338296890259, cost=0.06400588899850845
# Epoch 407: m=-0.39185863733291626, b=1.3792418241500854, cost=0.06349379569292068
# Epoch 408: m=-0.39230504631996155, b=1.381437063217163, cost=0.06298757344484329
# Epoch 409: m=-0.3927488625049591, b=1.3836196660995483, cost=0.062487173825502396
# Epoch 410: m=-0.3931901454925537, b=1.3857897520065308, cost=0.061992526054382324
# Epoch 411: m=-0.393628865480423, b=1.3879473209381104, cost=0.061503563076257706
# Epoch 412: m=-0.39406508207321167, b=1.390092372894287, cost=0.06102020666003227
# Epoch 413: m=-0.3944987654685974, b=1.3922250270843506, cost=0.06054243817925453
# Epoch 414: m=-0.3949299454689026, b=1.3943454027175903, cost=0.06007016450166702
# Epoch 415: m=-0.3953586518764496, b=1.396453619003296, cost=0.05960330739617348
# Epoch 416: m=-0.3957848846912384, b=1.3985496759414673, cost=0.059141818434000015
# Epoch 417: m=-0.39620864391326904, b=1.4006335735321045, cost=0.05868561565876007
# Epoch 418: m=-0.3966299593448639, b=1.4027055501937866, cost=0.058234699070453644
# Epoch 419: m=-0.39704886078834534, b=1.4047654867172241, cost=0.05778893083333969
# Epoch 420: m=-0.3974653482437134, b=1.406813621520996, cost=0.05734831467270851
# Epoch 421: m=-0.397879421710968, b=1.4088499546051025, cost=0.056912750005722046
# Epoch 422: m=-0.39829111099243164, b=1.4108744859695435, cost=0.056482184678316116
# Epoch 423: m=-0.39870044589042664, b=1.4128873348236084, cost=0.05605660006403923
# Epoch 424: m=-0.3991073966026306, b=1.414888620376587, cost=0.05563589930534363
# Epoch 425: m=-0.39951202273368835, b=1.416878342628479, cost=0.05522002652287483
# Epoch 426: m=-0.39991429448127747, b=1.4188566207885742, cost=0.05480893328785896
# Epoch 427: m=-0.40031424164772034, b=1.4208234548568726, cost=0.054402563720941544
# Epoch 428: m=-0.40071189403533936, b=1.4227789640426636, cost=0.05400088056921959
# Epoch 429: m=-0.4011072516441345, b=1.4247232675552368, cost=0.05360381305217743
# Epoch 430: m=-0.4015003442764282, b=1.4266563653945923, cost=0.05321129411458969
# Epoch 431: m=-0.40189117193222046, b=1.42857825756073, cost=0.05282329022884369
# Epoch 432: m=-0.40227973461151123, b=1.4304890632629395, cost=0.052439749240875244
# Epoch 433: m=-0.4026660621166229, b=1.4323889017105103, cost=0.052060626447200775
# Epoch 434: m=-0.40305015444755554, b=1.4342777729034424, cost=0.05168586224317551
# Epoch 435: m=-0.40343204140663147, b=1.4361556768417358, cost=0.05131540447473526
# Epoch 436: m=-0.4038117229938507, b=1.4380228519439697, cost=0.050949204713106155
# Epoch 437: m=-0.40418922901153564, b=1.4398791790008545, cost=0.050587210804224014
# Epoch 438: m=-0.4045645296573639, b=1.4417248964309692, cost=0.050229400396347046
# Epoch 439: m=-0.4049376845359802, b=1.4435598850250244, cost=0.04987567290663719
# Epoch 440: m=-0.40530869364738464, b=1.4453843832015991, cost=0.049526046961545944
# Epoch 441: m=-0.40567755699157715, b=1.4471982717514038, cost=0.04918041080236435
# Epoch 442: m=-0.4060443043708801, b=1.4490017890930176, cost=0.04883876442909241
# Epoch 443: m=-0.4064089357852936, b=1.4507948160171509, cost=0.04850102216005325
# Epoch 444: m=-0.4067714512348175, b=1.4525775909423828, cost=0.04816719517111778
# Epoch 445: m=-0.4071318805217743, b=1.4543499946594238, cost=0.04783718287944794
# Epoch 446: m=-0.40749022364616394, b=1.456112265586853, cost=0.04751100018620491
# Epoch 447: m=-0.40784651041030884, b=1.4578642845153809, cost=0.04718853905797005
# Epoch 448: m=-0.408200740814209, b=1.4596062898635864, cost=0.046869780868291855
# Epoch 449: m=-0.4085529148578644, b=1.4613381624221802, cost=0.04655470326542854
# Epoch 450: m=-0.4089030623435974, b=1.4630601406097412, cost=0.046243250370025635
# Epoch 451: m=-0.40925121307373047, b=1.46477210521698, cost=0.04593537747859955
# Epoch 452: m=-0.40959733724594116, b=1.4664742946624756, cost=0.0456310398876667
# Epoch 453: m=-0.4099414646625519, b=1.4681665897369385, cost=0.045330196619033813
# Epoch 454: m=-0.410283625125885, b=1.4698491096496582, cost=0.0450328104197979
# Epoch 455: m=-0.41062378883361816, b=1.4715219736099243, cost=0.044738855212926865
# Epoch 456: m=-0.4109620153903961, b=1.4731851816177368, cost=0.044448282569646835
# Epoch 457: m=-0.4112982749938965, b=1.4748388528823853, cost=0.04416104406118393
# Epoch 458: m=-0.41163259744644165, b=1.4764829874038696, cost=0.04387710243463516
# Epoch 459: m=-0.4119649827480316, b=1.47811758518219, cost=0.04359642416238785
# Epoch 460: m=-0.41229546070098877, b=1.4797427654266357, cost=0.043318990617990494
# Epoch 461: m=-0.4126240313053131, b=1.4813586473464966, cost=0.04304473474621773
# Epoch 462: m=-0.412950724363327, b=1.482965111732483, cost=0.042773615568876266
# Epoch 463: m=-0.4132755398750305, b=1.4845623970031738, cost=0.042505647987127304
# Epoch 464: m=-0.4135984778404236, b=1.4861503839492798, cost=0.042240723967552185
# Epoch 465: m=-0.4139195382595062, b=1.4877293109893799, cost=0.041978880763053894
# Epoch 466: m=-0.41423875093460083, b=1.4892990589141846, cost=0.041720032691955566
# Epoch 467: m=-0.4145561158657074, b=1.4908597469329834, cost=0.04146415367722511
# Epoch 468: m=-0.4148716628551483, b=1.492411494255066, cost=0.041211243718862534
# Epoch 469: m=-0.4151853919029236, b=1.4939543008804321, cost=0.04096122086048126
# Epoch 470: m=-0.4154973030090332, b=1.495488166809082, cost=0.040714066475629807
# Epoch 471: m=-0.41580742597579956, b=1.4970132112503052, cost=0.040469761937856674
# Epoch 472: m=-0.41611576080322266, b=1.4985294342041016, cost=0.04022826999425888
# Epoch 473: m=-0.4164223074913025, b=1.5000369548797607, cost=0.03998954966664314
# Epoch 474: m=-0.41672709584236145, b=1.5015357732772827, cost=0.03975358232855797
# Epoch 475: m=-0.41703012585639954, b=1.503026008605957, cost=0.03952031210064888
# Epoch 476: m=-0.41733139753341675, b=1.5045075416564941, cost=0.039289720356464386
# Epoch 477: m=-0.4176309406757355, b=1.5059806108474731, cost=0.03906181827187538
# Epoch 478: m=-0.4179287552833557, b=1.507445216178894, cost=0.038836486637592316
# Epoch 479: m=-0.41822484135627747, b=1.5089013576507568, cost=0.03861377015709877
# Epoch 480: m=-0.4185192286968231, b=1.5103490352630615, cost=0.03839360177516937
# Epoch 481: m=-0.41881194710731506, b=1.5117883682250977, cost=0.038176000118255615
# Epoch 482: m=-0.4191029667854309, b=1.5132194757461548, cost=0.03796086832880974
# Epoch 483: m=-0.41939228773117065, b=1.5146422386169434, cost=0.03774821758270264
# Epoch 484: m=-0.4196799397468567, b=1.5160568952560425, cost=0.03753802925348282
# Epoch 485: m=-0.4199659526348114, b=1.5174633264541626, cost=0.037330228835344315
# Epoch 486: m=-0.4202502965927124, b=1.5188616514205933, cost=0.037124838680028915
# Epoch 487: m=-0.4205330014228821, b=1.520251989364624, cost=0.036921799182891846
# Epoch 488: m=-0.4208140969276428, b=1.5216342210769653, cost=0.036721084266901016
# Epoch 489: m=-0.42109355330467224, b=1.5230084657669067, cost=0.036522701382637024
# Epoch 490: m=-0.4213714003562927, b=1.5243748426437378, cost=0.03632660582661629
# Epoch 491: m=-0.4216476380825043, b=1.5257333517074585, cost=0.03613273799419403
# Epoch 492: m=-0.4219222962856293, b=1.5270839929580688, cost=0.03594111278653145
# Epoch 493: m=-0.4221953749656677, b=1.5284268856048584, cost=0.03575168922543526
# Epoch 494: m=-0.42246687412261963, b=1.5297620296478271, cost=0.03556444123387337
# Epoch 495: m=-0.4227368235588074, b=1.531089425086975, cost=0.03537934273481369
# Epoch 496: m=-0.42300519347190857, b=1.5324091911315918, cost=0.03519637510180473
# Epoch 497: m=-0.4232720136642456, b=1.5337213277816772, cost=0.035015519708395004
# Epoch 498: m=-0.42353731393814087, b=1.535025954246521, cost=0.03483673185110092
# Epoch 499: m=-0.423801064491272, b=1.536323070526123, cost=0.03466000407934189
# Epoch 500: m=-0.4240632951259613, b=1.5376126766204834, cost=0.034485310316085815
# Epoch 501: m=-0.42432403564453125, b=1.5388948917388916, cost=0.03431262448430061
# Epoch 502: m=-0.4245832562446594, b=1.5401697158813477, cost=0.034141913056373596
# Epoch 503: m=-0.4248409867286682, b=1.5414371490478516, cost=0.03397316113114357
# Epoch 504: m=-0.4250972270965576, b=1.5426973104476929, cost=0.03380636125802994
# Epoch 505: m=-0.42535200715065, b=1.5439502000808716, cost=0.03364148363471031
# Epoch 506: m=-0.42560532689094543, b=1.5451958179473877, cost=0.03347848728299141
# Epoch 507: m=-0.42585715651512146, b=1.5464342832565308, cost=0.03331737965345383
# Epoch 508: m=-0.4261075556278229, b=1.5476655960083008, cost=0.03315812349319458
# Epoch 509: m=-0.4263564944267273, b=1.5488897562026978, cost=0.03300068899989128
# Epoch 510: m=-0.4266040027141571, b=1.5501068830490112, cost=0.032845087349414825
# Epoch 511: m=-0.4268500804901123, b=1.5513169765472412, cost=0.032691262662410736
# Epoch 512: m=-0.4270947277545929, b=1.5525201559066772, cost=0.03253920376300812
# Epoch 513: m=-0.42733797430992126, b=1.5537164211273193, cost=0.03238888457417488
# Epoch 514: m=-0.4275798201560974, b=1.5549057722091675, cost=0.032240308821201324
# Epoch 515: m=-0.4278202950954437, b=1.5560882091522217, cost=0.03209342435002327
# Epoch 516: m=-0.4280593693256378, b=1.5572638511657715, cost=0.03194824606180191
# Epoch 517: m=-0.4282970428466797, b=1.558432698249817, cost=0.03180472180247307
# Epoch 518: m=-0.4285333752632141, b=1.5595948696136475, cost=0.03166286274790764
# Epoch 519: m=-0.4287683367729187, b=1.5607503652572632, cost=0.031522613018751144
# Epoch 520: m=-0.42900195717811584, b=1.561899185180664, cost=0.03138399496674538
# Epoch 521: m=-0.42923420667648315, b=1.56304132938385, cost=0.031246952712535858
# Epoch 522: m=-0.4294651448726654, b=1.5641769170761108, cost=0.03111150488257408
# Epoch 523: m=-0.4296947419643402, b=1.5653059482574463, cost=0.030977610498666763
# Epoch 524: m=-0.42992299795150757, b=1.5664284229278564, cost=0.03084525279700756
# Epoch 525: m=-0.43014994263648987, b=1.5675444602966309, cost=0.03071442060172558
# Epoch 526: m=-0.4303755760192871, b=1.5686540603637695, cost=0.03058508224785328
# Epoch 527: m=-0.4305998980998993, b=1.5697572231292725, cost=0.03045724332332611
# Epoch 528: m=-0.4308229386806488, b=1.5708540678024292, cost=0.030330877751111984
# Epoch 529: m=-0.43104469776153564, b=1.5719445943832397, cost=0.03020595759153366
# Epoch 530: m=-0.4312651753425598, b=1.573028802871704, cost=0.030082469806075096
# Epoch 531: m=-0.4314843714237213, b=1.5741068124771118, cost=0.029960397630929947
# Epoch 532: m=-0.43170231580734253, b=1.575178623199463, cost=0.029839735478162766
# Epoch 533: m=-0.43191900849342346, b=1.5762442350387573, cost=0.02972046658396721
# Epoch 534: m=-0.4321344494819641, b=1.5773036479949951, cost=0.029602551832795143
# Epoch 535: m=-0.4323486387729645, b=1.5783569812774658, cost=0.02948600798845291
# Epoch 536: m=-0.43256160616874695, b=1.5794042348861694, cost=0.029370803385972977
# Epoch 537: m=-0.4327733516693115, b=1.580445408821106, cost=0.029256928712129593
# Epoch 538: m=-0.4329838454723358, b=1.581480622291565, cost=0.02914435788989067
# Epoch 539: m=-0.4331931471824646, b=1.5825098752975464, cost=0.029033087193965912
# Epoch 540: m=-0.4334012269973755, b=1.5835331678390503, cost=0.02892308123409748
# Epoch 541: m=-0.43360811471939087, b=1.5845506191253662, cost=0.02881435491144657
# Epoch 542: m=-0.43381381034851074, b=1.5855622291564941, cost=0.028706856071949005
# Epoch 543: m=-0.4340183436870575, b=1.586567997932434, cost=0.028600607067346573
# Epoch 544: m=-0.43422168493270874, b=1.587567925453186, cost=0.028495579957962036
# Epoch 545: m=-0.43442386388778687, b=1.5885621309280396, cost=0.028391757979989052
# Epoch 546: m=-0.4346248507499695, b=1.5895506143569946, cost=0.028289128094911575
# Epoch 547: m=-0.43482470512390137, b=1.5905333757400513, cost=0.028187673538923264
# Epoch 548: m=-0.43502339720726013, b=1.5915104150772095, cost=0.028087390586733818
# Epoch 549: m=-0.4352209270000458, b=1.5924818515777588, cost=0.02798827551305294
# Epoch 550: m=-0.4354173243045807, b=1.5934476852416992, cost=0.027890287339687347
# Epoch 551: m=-0.43561258912086487, b=1.5944079160690308, cost=0.027793416753411293
# Epoch 552: m=-0.4358067512512207, b=1.595362663269043, cost=0.027697673067450523
# Epoch 553: m=-0.4359997808933258, b=1.5963119268417358, cost=0.02760303020477295
# Epoch 554: m=-0.43619170784950256, b=1.5972557067871094, cost=0.02750946208834648
# Epoch 555: m=-0.4363825023174286, b=1.5981940031051636, cost=0.027416979894042015
# Epoch 556: m=-0.43657222390174866, b=1.599126935005188, cost=0.027325574308633804
# Epoch 557: m=-0.4367608428001404, b=1.6000545024871826, cost=0.02723519317805767
# Epoch 558: m=-0.43694835901260376, b=1.6009767055511475, cost=0.02714586816728115
# Epoch 559: m=-0.4371348023414612, b=1.6018935441970825, cost=0.027057554572820663
# Epoch 560: m=-0.43732017278671265, b=1.6028051376342773, cost=0.02697027288377285
# Epoch 561: m=-0.43750447034835815, b=1.603711485862732, cost=0.02688399888575077
# Epoch 562: m=-0.4376877248287201, b=1.6046125888824463, cost=0.02679869718849659
# Epoch 563: m=-0.4378699064254761, b=1.6055084466934204, cost=0.026714392006397247
# Epoch 564: m=-0.4380510449409485, b=1.6063991785049438, cost=0.02663104608654976
# Epoch 565: m=-0.43823111057281494, b=1.6072847843170166, cost=0.02654866687953472
# Epoch 566: m=-0.4384101629257202, b=1.6081652641296387, cost=0.02646723948419094
# Epoch 567: m=-0.4385881721973419, b=1.60904061794281, cost=0.026386728510260582
# Epoch 568: m=-0.43876513838768005, b=1.6099109649658203, cost=0.026307160034775734
# Epoch 569: m=-0.4389411211013794, b=1.6107763051986694, cost=0.026228515431284904
# Epoch 570: m=-0.43911606073379517, b=1.6116366386413574, cost=0.026150763034820557
# Epoch 571: m=-0.43929001688957214, b=1.6124920845031738, cost=0.026073893532156944
# Epoch 572: m=-0.43946295976638794, b=1.613342523574829, cost=0.02599792368710041
# Epoch 573: m=-0.43963488936424255, b=1.6141880750656128, cost=0.02592281438410282
# Epoch 574: m=-0.4398058354854584, b=1.615028738975525, cost=0.02584858611226082
# Epoch 575: m=-0.4399757981300354, b=1.6158645153045654, cost=0.025775205343961716
# Epoch 576: m=-0.44014477729797363, b=1.616695523262024, cost=0.02570265904068947
# Epoch 577: m=-0.44031280279159546, b=1.6175217628479004, cost=0.025630956515669823
# Epoch 578: m=-0.4404798448085785, b=1.6183432340621948, cost=0.025560075417160988
# Epoch 579: m=-0.4406459331512451, b=1.6191599369049072, cost=0.025490008294582367
# Epoch 580: m=-0.44081103801727295, b=1.6199719905853271, cost=0.025420745834708214
# Epoch 581: m=-0.44097521901130676, b=1.620779275894165, cost=0.025352269411087036
# Epoch 582: m=-0.44113844633102417, b=1.6215819120407104, cost=0.025284595787525177
# Epoch 583: m=-0.44130071997642517, b=1.622380018234253, cost=0.025217704474925995
# Epoch 584: m=-0.44146206974983215, b=1.623173475265503, cost=0.025151576846837997
# Epoch 585: m=-0.4416224956512451, b=1.62396240234375, cost=0.025086192414164543
# Epoch 586: m=-0.44178199768066406, b=1.6247466802597046, cost=0.025021573528647423
# Epoch 587: m=-0.441940575838089, b=1.6255264282226562, cost=0.024957703426480293
# Epoch 588: m=-0.4420982301235199, b=1.6263017654418945, cost=0.024894559755921364
# Epoch 589: m=-0.4422549605369568, b=1.6270725727081299, cost=0.02483215183019638
# Epoch 590: m=-0.44241079688072205, b=1.6278389692306519, cost=0.024770455434918404
# Epoch 591: m=-0.4425657391548157, b=1.6286009550094604, cost=0.024709468707442284
# Epoch 592: m=-0.44271978735923767, b=1.6293585300445557, cost=0.02464917302131653
# Epoch 593: m=-0.4428729712963104, b=1.6301116943359375, cost=0.02458958700299263
# Epoch 594: m=-0.44302526116371155, b=1.6308605670928955, cost=0.024530678987503052
# Epoch 595: m=-0.44317665696144104, b=1.6316051483154297, cost=0.024472439661622047
# Epoch 596: m=-0.4433271884918213, b=1.63234543800354, cost=0.024414872750639915
# Epoch 597: m=-0.4434768557548523, b=1.6330814361572266, cost=0.024357978254556656
# Epoch 598: m=-0.44362565875053406, b=1.6338131427764893, cost=0.024301737546920776
# Epoch 599: m=-0.4437735974788666, b=1.6345406770706177, cost=0.02424614131450653
# Epoch 600: m=-0.44392067193984985, b=1.6352640390396118, cost=0.024191180244088173
# Epoch 601: m=-0.4440669119358063, b=1.6359832286834717, cost=0.024136845022439957
# Epoch 602: m=-0.44421231746673584, b=1.6366982460021973, cost=0.024083135649561882
# Epoch 603: m=-0.44435688853263855, b=1.6374090909957886, cost=0.02403004840016365
# Epoch 604: m=-0.4445006251335144, b=1.6381158828735352, cost=0.02397758699953556
# Epoch 605: m=-0.4446435272693634, b=1.638818621635437, cost=0.023925716057419777
# Epoch 606: m=-0.44478559494018555, b=1.6395173072814941, cost=0.023874428123235703
# Epoch 607: m=-0.4449268579483032, b=1.6402119398117065, cost=0.023823745548725128
# Epoch 608: m=-0.44506728649139404, b=1.6409026384353638, cost=0.02377364970743656
# Epoch 609: m=-0.4452069103717804, b=1.6415892839431763, cost=0.023724107071757317
# Epoch 610: m=-0.4453457295894623, b=1.6422719955444336, cost=0.02367514930665493
# Epoch 611: m=-0.4454837739467621, b=1.6429507732391357, cost=0.023626763373613358
# Epoch 612: m=-0.4456210136413574, b=1.6436256170272827, cost=0.02357892505824566
# Epoch 613: m=-0.4457574486732483, b=1.6442965269088745, cost=0.023531632497906685
# Epoch 614: m=-0.4458931088447571, b=1.6449636220932007, cost=0.023484885692596436
# Epoch 615: m=-0.4460279643535614, b=1.6456269025802612, cost=0.023438677191734314
# Epoch 616: m=-0.44616207480430603, b=1.6462863683700562, cost=0.02339300699532032
# Epoch 617: m=-0.4462953805923462, b=1.6469420194625854, cost=0.023347852751612663
# Epoch 618: m=-0.44642794132232666, b=1.6475938558578491, cost=0.023303218185901642
# Epoch 619: m=-0.44655972719192505, b=1.6482418775558472, cost=0.023259101435542107
# Epoch 620: m=-0.44669073820114136, b=1.6488862037658691, cost=0.023215485736727715
# Epoch 621: m=-0.446821004152298, b=1.649526834487915, cost=0.02317238226532936
# Epoch 622: m=-0.4469505250453949, b=1.6501637697219849, cost=0.023129761219024658
# Epoch 623: m=-0.44707930088043213, b=1.6507970094680786, cost=0.023087644949555397
# Epoch 624: m=-0.44720733165740967, b=1.6514266729354858, cost=0.023046007379889488
# Epoch 625: m=-0.4473346471786499, b=1.652052640914917, cost=0.02300483174622059
# Epoch 626: m=-0.44746121764183044, b=1.6526750326156616, cost=0.02296414226293564
# Epoch 627: m=-0.4475870430469513, b=1.6532938480377197, cost=0.02292393520474434
# Epoch 628: m=-0.44771215319633484, b=1.6539090871810913, cost=0.02288416214287281
# Epoch 629: m=-0.4478365480899811, b=1.6545207500457764, cost=0.022844871506094933
# Epoch 630: m=-0.4479601979255676, b=1.655128836631775, cost=0.022806013002991676
# Epoch 631: m=-0.44808313250541687, b=1.6557334661483765, cost=0.02276761829853058
# Epoch 632: m=-0.4482053816318512, b=1.656334638595581, cost=0.02272966504096985
# Epoch 633: m=-0.4483269155025482, b=1.6569323539733887, cost=0.022692130878567696
# Epoch 634: m=-0.4484477639198303, b=1.6575266122817993, cost=0.022655045613646507
# Epoch 635: m=-0.4485678970813751, b=1.658117413520813, cost=0.0226183719933033
# Epoch 636: m=-0.448687344789505, b=1.6587048768997192, cost=0.022582126781344414
# Epoch 637: m=-0.44880610704421997, b=1.6592888832092285, cost=0.02254629321396351
# Epoch 638: m=-0.44892418384552, b=1.6598695516586304, cost=0.02251087687909603
# Epoch 639: m=-0.44904157519340515, b=1.6604468822479248, cost=0.02247587963938713
# Epoch 640: m=-0.44915831089019775, b=1.6610208749771118, cost=0.02244126796722412
# Epoch 641: m=-0.44927436113357544, b=1.6615915298461914, cost=0.022407062351703644
# Epoch 642: m=-0.4493897259235382, b=1.6621588468551636, cost=0.02237323671579361
# Epoch 643: m=-0.44950443506240845, b=1.6627229452133179, cost=0.02233981527388096
# Epoch 644: m=-0.44961848855018616, b=1.6632838249206543, cost=0.02230677753686905
# Epoch 645: m=-0.44973188638687134, b=1.6638414859771729, cost=0.022274108603596687
# Epoch 646: m=-0.449844628572464, b=1.6643959283828735, cost=0.022241823375225067
# Epoch 647: m=-0.4499567151069641, b=1.6649471521377563, cost=0.022209905087947845
# Epoch 648: m=-0.4500681757926941, b=1.6654951572418213, cost=0.02217835932970047
# Epoch 649: m=-0.45017898082733154, b=1.666040062904358, cost=0.022147180512547493
# Epoch 650: m=-0.45028913021087646, b=1.6665817499160767, cost=0.022116340696811676
# Epoch 651: m=-0.45039865374565125, b=1.667120337486267, cost=0.022085869684815407
# Epoch 652: m=-0.4505075514316559, b=1.6676558256149292, cost=0.02205576002597809
# Epoch 653: m=-0.4506158232688904, b=1.668188214302063, cost=0.022025974467396736
# Epoch 654: m=-0.45072346925735474, b=1.6687175035476685, cost=0.021996550261974335
# Epoch 655: m=-0.45083048939704895, b=1.6692438125610352, cost=0.021967455744743347
# Epoch 656: m=-0.450936883687973, b=1.6697670221328735, cost=0.021938689053058624
# Epoch 657: m=-0.45104265213012695, b=1.6702872514724731, cost=0.021910272538661957
# Epoch 658: m=-0.45114782452583313, b=1.670804500579834, cost=0.02188216522336006
# Epoch 659: m=-0.45125240087509155, b=1.671318769454956, cost=0.021854382008314133
# Epoch 660: m=-0.4513563811779022, b=1.6718300580978394, cost=0.021826928481459618
# Epoch 661: m=-0.45145976543426514, b=1.6723383665084839, cost=0.021799784153699875
# Epoch 662: m=-0.4515625238418579, b=1.6728438138961792, cost=0.021772941574454308
# Epoch 663: m=-0.4516647160053253, b=1.6733462810516357, cost=0.021746430546045303
# Epoch 664: m=-0.45176631212234497, b=1.673845887184143, cost=0.021720200777053833
# Epoch 665: m=-0.45186731219291687, b=1.6743426322937012, cost=0.021694287657737732
# Epoch 666: m=-0.4519677460193634, b=1.67483651638031, cost=0.021668672561645508
# Epoch 667: m=-0.4520675837993622, b=1.6753275394439697, cost=0.02164333686232567
# Epoch 668: m=-0.4521668553352356, b=1.6758157014846802, cost=0.0216183103621006
# Epoch 669: m=-0.45226556062698364, b=1.676301121711731, cost=0.02159355953335762
# Epoch 670: m=-0.4523636996746063, b=1.6767836809158325, cost=0.02156909741461277
# Epoch 671: m=-0.45246127247810364, b=1.6772634983062744, cost=0.02154492400586605
# Epoch 672: m=-0.4525582790374756, b=1.6777405738830566, cost=0.021521011367440224
# Epoch 673: m=-0.45265471935272217, b=1.6782147884368896, cost=0.02149738371372223
# Epoch 674: m=-0.4527505934238434, b=1.6786863803863525, cost=0.021474026143550873
# Epoch 675: m=-0.4528459310531616, b=1.6791552305221558, cost=0.021450936794281006
# Epoch 676: m=-0.4529407322406769, b=1.6796213388442993, cost=0.02142811380326748
# Epoch 677: m=-0.4530349671840668, b=1.6800847053527832, cost=0.021405553445219994
# Epoch 678: m=-0.4531286656856537, b=1.680545449256897, cost=0.021383266896009445
# Epoch 679: m=-0.4532218277454376, b=1.6810035705566406, cost=0.021361224353313446
# Epoch 680: m=-0.4533144235610962, b=1.6814590692520142, cost=0.021339422091841698
# Epoch 681: m=-0.45340651273727417, b=1.6819119453430176, cost=0.021317891776561737
# Epoch 682: m=-0.45349806547164917, b=1.6823621988296509, cost=0.02129659615457058
# Epoch 683: m=-0.4535891115665436, b=1.682809829711914, cost=0.02127554640173912
# Epoch 684: m=-0.453679621219635, b=1.6832548379898071, cost=0.021254733204841614
# Epoch 685: m=-0.45376959443092346, b=1.6836973428726196, cost=0.021234173327684402
# Epoch 686: m=-0.4538590610027313, b=1.684137225151062, cost=0.021213838830590248
# Epoch 687: m=-0.4539479911327362, b=1.6845746040344238, cost=0.02119375579059124
# Epoch 688: m=-0.4540364146232605, b=1.685009479522705, cost=0.021173890680074692
# Epoch 689: m=-0.4541243314743042, b=1.6854418516159058, cost=0.0211542546749115
# Epoch 690: m=-0.4542117416858673, b=1.6858717203140259, cost=0.021134832873940468
# Epoch 691: m=-0.45429864525794983, b=1.6862990856170654, cost=0.021115649491548538
# Epoch 692: m=-0.45438504219055176, b=1.686724066734314, cost=0.02109668031334877
# Epoch 693: m=-0.4544709622859955, b=1.687146544456482, cost=0.02107793465256691
# Epoch 694: m=-0.4545563757419586, b=1.6875666379928589, cost=0.02105940878391266
# Epoch 695: m=-0.45464131236076355, b=1.6879842281341553, cost=0.02104107476770878
# Epoch 696: m=-0.4547257423400879, b=1.6883994340896606, cost=0.0210229754447937
# Epoch 697: m=-0.45480969548225403, b=1.688812255859375, cost=0.021005071699619293
# Epoch 698: m=-0.45489317178726196, b=1.6892226934432983, cost=0.02098737098276615
# Epoch 699: m=-0.4549761414527893, b=1.6896307468414307, cost=0.020969882607460022
# Epoch 700: m=-0.45505863428115845, b=1.690036416053772, cost=0.02095259167253971
# Epoch 701: m=-0.4551406502723694, b=1.6904398202896118, cost=0.020935501903295517
# Epoch 702: m=-0.4552222192287445, b=1.6908408403396606, cost=0.020918605849146843
# Epoch 703: m=-0.4553033113479614, b=1.691239595413208, cost=0.020901912823319435
# Epoch 704: m=-0.45538392663002014, b=1.691636085510254, cost=0.0208854041993618
# Epoch 705: m=-0.45546406507492065, b=1.6920301914215088, cost=0.020869070664048195
# Epoch 706: m=-0.45554375648498535, b=1.6924220323562622, cost=0.02085295133292675
# Epoch 707: m=-0.45562297105789185, b=1.6928116083145142, cost=0.020837003365159035
# Epoch 708: m=-0.4557017385959625, b=1.6931990385055542, cost=0.020821241661906242
# Epoch 709: m=-0.4557800590991974, b=1.6935842037200928, cost=0.020805655047297478
# Epoch 710: m=-0.45585793256759644, b=1.6939671039581299, cost=0.020790250971913338
# Epoch 711: m=-0.45593535900115967, b=1.694347858428955, cost=0.02077503502368927
# Epoch 712: m=-0.4560123383998871, b=1.6947263479232788, cost=0.020759975537657738
# Epoch 713: m=-0.4560888707637787, b=1.6951026916503906, cost=0.020745109766721725
# Epoch 714: m=-0.4561649560928345, b=1.6954768896102905, cost=0.020730402320623398
# Epoch 715: m=-0.45624059438705444, b=1.6958489418029785, cost=0.0207158662378788
# Epoch 716: m=-0.456315815448761, b=1.6962188482284546, cost=0.020701488479971886
# Epoch 717: m=-0.4563905894756317, b=1.6965866088867188, cost=0.020687280222773552
# Epoch 718: m=-0.456464946269989, b=1.696952223777771, cost=0.020673243328928947
# Epoch 719: m=-0.4565388858318329, b=1.6973156929016113, cost=0.02065936103463173
# Epoch 720: m=-0.45661237835884094, b=1.6976771354675293, cost=0.020645644515752792
# Epoch 721: m=-0.45668545365333557, b=1.6980364322662354, cost=0.020632071420550346
# Epoch 722: m=-0.4567580819129944, b=1.698393702507019, cost=0.02061866596341133
# Epoch 723: m=-0.45683032274246216, b=1.6987489461898804, cost=0.020605415105819702
# Epoch 724: m=-0.4569021463394165, b=1.6991020441055298, cost=0.02059231512248516
# Epoch 725: m=-0.4569735527038574, b=1.6994531154632568, cost=0.020579373463988304
# Epoch 726: m=-0.4570445418357849, b=1.6998021602630615, cost=0.02056656964123249
# Epoch 727: m=-0.457115113735199, b=1.7001491785049438, cost=0.020553920418024063
# Epoch 728: m=-0.4571852684020996, b=1.7004942893981934, cost=0.020541412755846977
# Epoch 729: m=-0.4572550356388092, b=1.7008373737335205, cost=0.020529046654701233
# Epoch 730: m=-0.45732438564300537, b=1.7011784315109253, cost=0.02051681838929653
# Epoch 731: m=-0.4573933482170105, b=1.7015175819396973, cost=0.02050473727285862
# Epoch 732: m=-0.4574619233608246, b=1.7018547058105469, cost=0.020492805168032646
# Epoch 733: m=-0.45753008127212524, b=1.7021899223327637, cost=0.020481005311012268
# Epoch 734: m=-0.45759785175323486, b=1.7025232315063477, cost=0.02046932466328144
# Epoch 735: m=-0.45766523480415344, b=1.7028546333312988, cost=0.02045780047774315
# Epoch 736: m=-0.457732230424881, b=1.7031841278076172, cost=0.02044638618826866
# Epoch 737: m=-0.4577988386154175, b=1.7035117149353027, cost=0.020435115322470665
# Epoch 738: m=-0.45786505937576294, b=1.7038373947143555, cost=0.020423969253897667
# Epoch 739: m=-0.45793089270591736, b=1.7041611671447754, cost=0.020412961021065712
# Epoch 740: m=-0.4579963684082031, b=1.704483151435852, cost=0.020402081310749054
# Epoch 741: m=-0.45806145668029785, b=1.704803228378296, cost=0.0203913152217865
# Epoch 742: m=-0.4581261873245239, b=1.7051215171813965, cost=0.020380675792694092
# Epoch 743: m=-0.45819053053855896, b=1.7054378986358643, cost=0.020370163023471832
# Epoch 744: m=-0.45825448632240295, b=1.7057524919509888, cost=0.020359767600893974
# Epoch 745: m=-0.4583180844783783, b=1.70606529712677, cost=0.02034948393702507
# Epoch 746: m=-0.458381325006485, b=1.706376314163208, cost=0.02033933624625206
# Epoch 747: m=-0.458444207906723, b=1.7066854238510132, cost=0.02032928168773651
# Epoch 748: m=-0.45850670337677, b=1.7069928646087646, cost=0.020319368690252304
# Epoch 749: m=-0.45856887102127075, b=1.7072985172271729, cost=0.020309558138251305
# Epoch 750: m=-0.45863065123558044, b=1.7076023817062378, cost=0.020299848169088364
# Epoch 751: m=-0.45869210362434387, b=1.7079044580459595, cost=0.020290270447731018
# Epoch 752: m=-0.45875316858291626, b=1.7082048654556274, cost=0.020280783995985985
# Epoch 753: m=-0.4588139057159424, b=1.7085034847259521, cost=0.0202714204788208
# Epoch 754: m=-0.45887428522109985, b=1.7088004350662231, cost=0.020262161269783974
# Epoch 755: m=-0.45893430709838867, b=1.7090955972671509, cost=0.020253004506230354
# Epoch 756: m=-0.4589940011501312, b=1.709389090538025, cost=0.02024395763874054
# Epoch 757: m=-0.4590533375740051, b=1.7096809148788452, cost=0.02023502066731453
# Epoch 758: m=-0.45911234617233276, b=1.7099710702896118, cost=0.020226171240210533
# Epoch 759: m=-0.45917099714279175, b=1.7102595567703247, cost=0.02021743357181549
# Epoch 760: m=-0.45922932028770447, b=1.7105463743209839, cost=0.02020879276096821
# Epoch 761: m=-0.4592873156070709, b=1.7108315229415894, cost=0.020200256258249283
# Epoch 762: m=-0.4593449532985687, b=1.7111150026321411, cost=0.020191803574562073
# Epoch 763: m=-0.45940226316452026, b=1.7113968133926392, cost=0.020183470100164413
# Epoch 764: m=-0.45945924520492554, b=1.711677074432373, cost=0.02017521858215332
# Epoch 765: m=-0.45951589941978455, b=1.7119556665420532, cost=0.020167065784335136
# Epoch 766: m=-0.4595722258090973, b=1.7122327089309692, cost=0.020159007981419563
# Epoch 767: m=-0.45962822437286377, b=1.7125080823898315, cost=0.020151028409600258
# Epoch 768: m=-0.45968392491340637, b=1.7127819061279297, cost=0.020143166184425354
# Epoch 769: m=-0.4597392678260803, b=1.7130541801452637, cost=0.020135369151830673
# Epoch 770: m=-0.4597943127155304, b=1.7133249044418335, cost=0.0201276745647192
# Epoch 771: m=-0.4598490297794342, b=1.7135939598083496, cost=0.02012006565928459
# Epoch 772: m=-0.45990344882011414, b=1.7138614654541016, cost=0.020112548023462296
# Epoch 773: m=-0.4599575400352478, b=1.7141274213790894, cost=0.02010512351989746
# Epoch 774: m=-0.4600113332271576, b=1.7143919467926025, cost=0.020097775384783745
# Epoch 775: m=-0.4600647985935211, b=1.7146549224853516, cost=0.020090514793992043
# Epoch 776: m=-0.46011796593666077, b=1.7149163484573364, cost=0.020083323121070862
# Epoch 777: m=-0.46017083525657654, b=1.7151762247085571, cost=0.020076226443052292
# Epoch 778: m=-0.46022337675094604, b=1.7154346704483032, cost=0.020069222897291183
# Epoch 779: m=-0.4602756202220917, b=1.7156915664672852, cost=0.020062284544110298
# Epoch 780: m=-0.4603275656700134, b=1.7159470319747925, cost=0.020055431872606277
# Epoch 781: m=-0.4603792130947113, b=1.7162010669708252, cost=0.020048655569553375
# Epoch 782: m=-0.4604305624961853, b=1.7164535522460938, cost=0.02004195749759674
# Epoch 783: m=-0.4604816138744354, b=1.7167046070098877, cost=0.020035337656736374
# Epoch 784: m=-0.46053236722946167, b=1.716954231262207, cost=0.020028790459036827
# Epoch 785: m=-0.4605828523635864, b=1.7172024250030518, cost=0.020022321492433548
# Epoch 786: m=-0.4606330096721649, b=1.7174491882324219, cost=0.020015928894281387
# Epoch 787: m=-0.4606828987598419, b=1.7176945209503174, cost=0.0200096033513546
# Epoch 788: m=-0.46073248982429504, b=1.7179384231567383, cost=0.020003344863653183

# %%
y
# Out:
# tensor([ 1.8600,  1.3100,  0.6200,  0.3300,  0.0900, -0.6700, -1.2300, -1.3700])
